# %% [markdown]
# <a href="https://colab.research.google.com/github/heesukjang/W207_AppliedML_Fall2022/blob/main/12_4_255pm_processed_images_ZIP_toTeam_withAugmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
import time
import random
import joblib
import glob
import random
from itertools import product
import gc
import subprocess
import shutil
import copy
import statistics as st
from scipy import stats
from google.colab import files

from imutils import rotate as rotate
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import matplotlib.patches as patches
from matplotlib.patches import Polygon
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix
from skimage.color import gray2rgb
import skimage.io as skio
from keras.utils.layer_utils import count_params
from tensorflow.keras.layers import Concatenate

from sklearn.utils import shuffle
from sklearn.decomposition import PCA
from sklearn.decomposition import IncrementalPCA
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn import metrics
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import classification_report, cohen_kappa_score, zero_one_loss
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import train_test_split, GridSearchCV

# from tensorflow.keras.preprocessing.image import array_to_img
# from tensorflow.keras.preprocessing.image import img_to_array
# from tensorflow.keras.preprocessing.image import load_img
# from tensorflow.keras.preprocessing.image import save_img

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.losses import BinaryCrossentropy, CategoricalCrossentropy
#from livelossplot import PlotLossesKeras

from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Multiply
# from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import RandomFlip, RandomZoom, RandomRotation, Conv2D, AveragePooling2D, GlobalAveragePooling2D, MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D, Input, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.layers import PReLU, ReLU, LeakyReLU
from keras.layers.core import Activation
from keras.layers.convolutional import SeparableConv1D
from keras.layers.convolutional import SeparableConv2D 
from keras.layers.core import Activation
from tensorflow.keras.optimizers import Adam, SGD, Adadelta, Adagrad, RMSprop
from tensorflow.keras.models import Sequential

from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.densenet import *
from keras.applications.resnet import ResNet152
from tensorflow.keras.applications import ResNet152V2
from keras.applications.nasnet import NASNetMobile
from keras.applications.nasnet import NASNetLarge
from keras.applications.nasnet import preprocess_input
from keras.applications import MobileNetV2
from keras.applications.xception import Xception
from keras.applications.inception_v3 import *


from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img, save_img
from tensorflow.python.ops.numpy_ops import np_config
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler

from keras.models import Model
from tensorflow.keras import regularizers
from tensorflow.keras.regularizers import l1
from tensorflow.keras.regularizers import l2
from keras.models import load_model
from IPython.display import Image
from tensorflow.keras.applications import ResNet152V2, VGG16, VGG19

tf.get_logger().setLevel('INFO')

import cv2 as cv
import skimage.io as io

import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter("ignore", category=DeprecationWarning)

# Required to read the data from Kaggle
from google.colab import drive
# drive.mount('/content/gdrive')
# os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/MyDrive/Kaggle"

from google.colab import drive
drive.mount('/content/gdrive')

import logging

# get TF logger
log = logging.getLogger('tensorflow') # tell it to log it to a file
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# # send text data to a file
# # when colab crashes and force to terminate, go see the file and find out where the implementation left off and restart your code from there
# fh = logging.FileHandler('tensorflow.log')
# fh.setLevel(logging.DEBUG)
# fh.setFormatter(formatter)
# log.addHandler(fh)

# %%
# #send plots to a file 
# plt.savefig('books_read.png')

# %%
# tf.keras.utils.plot_model(model)

# %%
# !pip install -q -U keras-tuner
import keras_tuner as kt

# %%
# !unzip gdrive/MyDrive/Kaggle/CNN_IDC/Dataset.zip
# Out:
# Archive:  gdrive/MyDrive/Kaggle/CNN_IDC/Dataset.zip
# replace Dataset/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# delete a full folder including all its files and subfolders
# !rm -rf processed_images/

# %%
# !ls -ltr Dataset
# Out:
# total 12
# drwxr-xr-x 4 root root 4096 Oct  4 01:10 Test
# drwxr-xr-x 4 root root 4096 Oct  4 01:10 Train
# drwxr-xr-x 4 root root 4096 Oct  4 01:10 Validate

# %%
# ls -ltr: List the contents of the current directory in the long listing format ( -l ), 
#   sorted by modification time ( -t ) in reverse order ( -r ) of all files and directories beginning with file* .
# wc -l: count the number of lines

# !ls -ltr Dataset/Train/0|wc -l
# !ls -ltr Dataset/Train/1|wc -l

# !ls -ltr Dataset/Test/0|wc -l
# !ls -ltr Dataset/Test/1|wc -l

# !ls -ltr Dataset/Validate/0|wc -l
# !ls -ltr Dataset/Validate/1|wc -l
# Out:
# 401
# 401
# 101
# 101
# 101
# 101

# %%
val_image_directory = '/content/Dataset/Validate'
train_image_directory = '/content/Dataset/Train'
test_image_directory = '/content/Dataset/Test'
directory_path = '/content/Dataset'

tgt_directory_path = '/content/processed_images'
tgt_train_1_image_path = '/content/processed_images/train/1/'
tgt_train_0_image_path = '/content/processed_images/train/0/'
tgt_val_1_image_path = '/content/processed_images/val/1/'
tgt_val_0_image_path = '/content/processed_images/val/0/'
tgt_test_1_image_path = '/content/processed_images/test/1/'
tgt_test_0_image_path = '/content/processed_images/test/0/'

tgt_path_list = [tgt_train_1_image_path, tgt_train_0_image_path,
                 tgt_val_1_image_path, tgt_val_0_image_path,
                 tgt_test_1_image_path, tgt_test_0_image_path
                ]

# %%
def preprocess(data_dir):
  images_path_1 = [data_dir + '/' +  dir + '/' for dir in os.listdir(data_dir) if dir != '.DS_Store'][0]
  print('images_path_1:' ,images_path_1)
  images_path_0 = [data_dir + '/' +  dir + '/' for dir in os.listdir(data_dir) if dir != '.DS_Store'][1]
  print('images_path_0:' ,images_path_0)
  images_list_1 = [images_path_1 + file for file in list(os.walk(images_path_1))[0][2] if file[0] != '.']
  images_list_0 = [images_path_0 + file for file in list(os.walk(images_path_0))[0][2] if file[0] != '.']
  print('\nimages_list_1:' ,images_list_1)
  print('images_list_0:' ,images_list_0)

  return images_list_1, images_list_0

# %%
train_1_images_list, train_0_images_list = preprocess(train_image_directory)
test_1_images_list, test_0_images_list = preprocess(test_image_directory)
val_1_images_list, val_0_images_list = preprocess(val_image_directory)

print('\ntrain_1_images_list[0]',train_1_images_list[0])
print('train_0_images_list[0]',train_0_images_list[0])
# Out:
# images_path_1: /content/Dataset/Train/1/
# images_path_0: /content/Dataset/Train/0/
#
# images_list_1: ['/content/Dataset/Train/1/10269_idx5_x1351_y801_class1.png', '/content/Dataset/Train/1/9175_idx5_x1801_y201_class1.png', '/content/Dataset/Train/1/13613_idx5_x2201_y2001_class1.png', '/content/Dataset/Train/1/9023_idx5_x1351_y1751_class1.png', '/content/Dataset/Train/1/9255_idx5_x2901_y901_class1.png', '/content/Dataset/Train/1/16553_idx5_x601_y1551_class1.png', '/content/Dataset/Train/1/12817_idx5_x1901_y851_class1.png', '/content/Dataset/Train/1/14188_idx5_x1551_y1751_class1.png', '/content/Dataset/Train/1/12752_idx5_x2851_y1401_class1.png', '/content/Dataset/Train/1/12901_idx5_x2151_y851_class1.png', '/content/Dataset/Train/1/9261_idx5_x1101_y951_class1.png', '/content/Dataset/Train/1/12751_idx5_x1201_y1301_class1.png', '/content/Dataset/Train/1/12908_idx5_x2251_y1551_class1.png', '/content/Dataset/Train/1/10277_idx5_x751_y1201_class1.png', '/content/Dataset/Train/1/8867_idx5_x951_y1101_class1.png', '/content/Dataset/Train/1/10273_idx5_x1801_y1651_class1.png', '/content/Dataset/Train/1/9041_idx5_x2301_y1501_class1.png', '/content/Dataset/Train/1/8864_idx5_x1801_y2151_class1.png', '/content/Dataset/Train/1/12891_idx5_x551_y1001_class1.png', '/content/Dataset/Train/1/15902_idx5_x2451_y1651_class1.png', '/content/Dataset/Train/1/8864_idx5_x1701_y2401_class1.png', '/content/Dataset/Train/1/8975_idx5_x1501_y1401_class1.png', '/content/Dataset/Train/1/12826_idx5_x2801_y451_class1.png', '/content/Dataset/Train/1/10256_idx5_x1801_y1151_class1.png', '/content/Dataset/Train/1/9044_idx5_x701_y601_class1.png', '/content/Dataset/Train/1/14078_idx5_x1151_y901_class1.png', '/content/Dataset/Train/1/9250_idx5_x851_y1101_class1.png', '/content/Dataset/Train/1/9077_idx5_x2401_y751_class1.png', '/content/Dataset/Train/1/12880_idx5_x901_y1201_class1.png', '/content/Dataset/Train/1/15902_idx5_x2201_y1401_class1.png', '/content/Dataset/Train/1/8980_idx5_x1001_y1201_class1.png', '/content/Dataset/Train/1/12818_idx5_x1651_y951_class1.png', '/content/Dataset/Train/1/10273_idx5_x1501_y751_class1.png', '/content/Dataset/Train/1/16896_idx5_x251_y1151_class1.png', '/content/Dataset/Train/1/16554_idx5_x351_y1301_class1.png', '/content/Dataset/Train/1/12897_idx5_x2201_y551_class1.png', '/content/Dataset/Train/1/12873_idx5_x1251_y351_class1.png', '/content/Dataset/Train/1/12752_idx5_x2601_y501_class1.png', '/content/Dataset/Train/1/10264_idx5_x1701_y701_class1.png', '/content/Dataset/Train/1/16570_idx5_x1701_y1501_class1.png', '/content/Dataset/Train/1/14079_idx5_x1201_y1051_class1.png', '/content/Dataset/Train/1/15634_idx5_x1001_y1551_class1.png', '/content/Dataset/Train/1/12906_idx5_x1301_y1601_class1.png', '/content/Dataset/Train/1/12907_idx5_x2301_y1601_class1.png', '/content/Dataset/Train/1/9267_idx5_x2201_y801_class1.png', '/content/Dataset/Train/1/12906_idx5_x2201_y1551_class1.png', '/content/Dataset/Train/1/13616_idx5_x1401_y2201_class1.png', '/content/Dataset/Train/1/15902_idx5_x2651_y1401_class1.png', '/content/Dataset/Train/1/15633_idx5_x1401_y651_class1.png', '/content/Dataset/Train/1/10299_idx5_x1601_y1201_class1.png', '/content/Dataset/Train/1/9324_idx5_x1051_y351_class1.png', '/content/Dataset/Train/1/13402_idx5_x2301_y51_class1.png', '/content/Dataset/Train/1/12823_idx5_x3351_y901_class1.png', '/content/Dataset/Train/1/12751_idx5_x2601_y751_class1.png', '/content/Dataset/Train/1/12817_idx5_x1801_y901_class1.png', '/content/Dataset/Train/1/15471_idx5_x2051_y951_class1.png', '/content/Dataset/Train/1/13616_idx5_x1901_y1151_class1.png', '/content/Dataset/Train/1/9346_idx5_x1701_y1901_class1.png', '/content/Dataset/Train/1/9022_idx5_x2451_y1151_class1.png', '/content/Dataset/Train/1/12935_idx5_x1501_y1351_class1.png', '/content/Dataset/Train/1/15515_idx5_x251_y951_class1.png', '/content/Dataset/Train/1/14154_idx5_x2051_y1251_class1.png', '/content/Dataset/Train/1/12910_idx5_x651_y51_class1.png', '/content/Dataset/Train/1/9173_idx5_x2401_y1901_class1.png', '/content/Dataset/Train/1/8917_idx5_x1051_y601_class1.png', '/content/Dat ...
# images_list_0: ['/content/Dataset/Train/0/9256_idx5_x1901_y51_class0.png', '/content/Dataset/Train/0/9073_idx5_x2851_y1251_class0.png', '/content/Dataset/Train/0/10292_idx5_x3451_y1151_class0.png', '/content/Dataset/Train/0/10302_idx5_x501_y1701_class0.png', '/content/Dataset/Train/0/12879_idx5_x201_y301_class0.png', '/content/Dataset/Train/0/13693_idx5_x2601_y2101_class0.png', '/content/Dataset/Train/0/12821_idx5_x901_y451_class0.png', '/content/Dataset/Train/0/10282_idx5_x1351_y2501_class0.png', '/content/Dataset/Train/0/12750_idx5_x1651_y1601_class0.png', '/content/Dataset/Train/0/8959_idx5_x1751_y2201_class0.png', '/content/Dataset/Train/0/14156_idx5_x2001_y401_class0.png', '/content/Dataset/Train/0/13460_idx5_x351_y1651_class0.png', '/content/Dataset/Train/0/10295_idx5_x1251_y751_class0.png', '/content/Dataset/Train/0/15902_idx5_x2951_y2501_class0.png', '/content/Dataset/Train/0/16550_idx5_x1351_y2001_class0.png', '/content/Dataset/Train/0/12907_idx5_x2201_y1401_class0.png', '/content/Dataset/Train/0/14156_idx5_x2501_y2151_class0.png', '/content/Dataset/Train/0/12626_idx5_x1551_y1001_class0.png', '/content/Dataset/Train/0/15515_idx5_x1551_y1001_class0.png', '/content/Dataset/Train/0/8975_idx5_x1401_y2501_class0.png', '/content/Dataset/Train/0/15902_idx5_x301_y751_class0.png', '/content/Dataset/Train/0/14156_idx5_x551_y1401_class0.png', '/content/Dataset/Train/0/9078_idx5_x601_y1151_class0.png', '/content/Dataset/Train/0/12910_idx5_x401_y251_class0.png', '/content/Dataset/Train/0/10307_idx5_x2101_y751_class0.png', '/content/Dataset/Train/0/12896_idx5_x2301_y2051_class0.png', '/content/Dataset/Train/0/12934_idx5_x2901_y2551_class0.png', '/content/Dataset/Train/0/12820_idx5_x1801_y1451_class0.png', '/content/Dataset/Train/0/9323_idx5_x1501_y1851_class0.png', '/content/Dataset/Train/0/10279_idx5_x2451_y301_class0.png', '/content/Dataset/Train/0/9181_idx5_x401_y1051_class0.png', '/content/Dataset/Train/0/12750_idx5_x351_y1401_class0.png', '/content/Dataset/Train/0/13024_idx5_x2201_y1401_class0.png', '/content/Dataset/Train/0/13460_idx5_x1751_y901_class0.png', '/content/Dataset/Train/0/10268_idx5_x1351_y51_class0.png', '/content/Dataset/Train/0/12947_idx5_x2801_y651_class0.png', '/content/Dataset/Train/0/16014_idx5_x1751_y1151_class0.png', '/content/Dataset/Train/0/12749_idx5_x2201_y1401_class0.png', '/content/Dataset/Train/0/16014_idx5_x1401_y251_class0.png', '/content/Dataset/Train/0/13401_idx5_x1351_y1351_class0.png', '/content/Dataset/Train/0/10262_idx5_x301_y1151_class0.png', '/content/Dataset/Train/0/10275_idx5_x651_y651_class0.png', '/content/Dataset/Train/0/10285_idx5_x1701_y551_class0.png', '/content/Dataset/Train/0/12954_idx5_x1651_y2951_class0.png', '/content/Dataset/Train/0/12934_idx5_x951_y2251_class0.png', '/content/Dataset/Train/0/14155_idx5_x2401_y2051_class0.png', '/content/Dataset/Train/0/16570_idx5_x2801_y1151_class0.png', '/content/Dataset/Train/0/8863_idx5_x551_y601_class0.png', '/content/Dataset/Train/0/9078_idx5_x2201_y2001_class0.png', '/content/Dataset/Train/0/9173_idx5_x1151_y351_class0.png', '/content/Dataset/Train/0/10274_idx5_x851_y651_class0.png', '/content/Dataset/Train/0/12826_idx5_x451_y1201_class0.png', '/content/Dataset/Train/0/8867_idx5_x1401_y1801_class0.png', '/content/Dataset/Train/0/12910_idx5_x3351_y1101_class0.png', '/content/Dataset/Train/0/15632_idx5_x3101_y2551_class0.png', '/content/Dataset/Train/0/12749_idx5_x1101_y2001_class0.png', '/content/Dataset/Train/0/12822_idx5_x1951_y1151_class0.png', '/content/Dataset/Train/0/12911_idx5_x2301_y251_class0.png', '/content/Dataset/Train/0/10278_idx5_x1001_y1701_class0.png', '/content/Dataset/Train/0/9036_idx5_x2651_y1651_class0.png', '/content/Dataset/Train/0/8956_idx5_x2601_y1251_class0.png', '/content/Dataset/Train/0/12908_idx5_x1801_y501_class0.png', '/content/Dataset/Train/0/9346_idx5_x1001_y751_class0.png', '/content/Dataset/Train/0/12749_idx5_x2201_y551_class0.png', '/content/Dataset/Train/0/14156_idx5_x601_y1501_class0.png', '/content ...
# images_path_1: /content/Dataset/Test/1/
# images_path_0: /content/Dataset/Test/0/
#
# images_list_1: ['/content/Dataset/Test/1/14191_idx5_x2001_y2401_class1.png', '/content/Dataset/Test/1/12826_idx5_x2901_y651_class1.png', '/content/Dataset/Test/1/10273_idx5_x2501_y1201_class1.png', '/content/Dataset/Test/1/13021_idx5_x1951_y701_class1.png', '/content/Dataset/Test/1/9077_idx5_x801_y1801_class1.png', '/content/Dataset/Test/1/15903_idx5_x1251_y701_class1.png', '/content/Dataset/Test/1/8951_idx5_x1351_y951_class1.png', '/content/Dataset/Test/1/16167_idx5_x1751_y1251_class1.png', '/content/Dataset/Test/1/15471_idx5_x1851_y901_class1.png', '/content/Dataset/Test/1/13404_idx5_x2501_y1651_class1.png', '/content/Dataset/Test/1/9176_idx5_x1401_y1451_class1.png', '/content/Dataset/Test/1/12870_idx5_x401_y2501_class1.png', '/content/Dataset/Test/1/10279_idx5_x2351_y1401_class1.png', '/content/Dataset/Test/1/9345_idx5_x2801_y201_class1.png', '/content/Dataset/Test/1/10275_idx5_x1201_y1001_class1.png', '/content/Dataset/Test/1/14082_idx5_x1551_y1701_class1.png', '/content/Dataset/Test/1/10275_idx5_x2201_y1201_class1.png', '/content/Dataset/Test/1/10301_idx5_x1401_y951_class1.png', '/content/Dataset/Test/1/12867_idx5_x2151_y2151_class1.png', '/content/Dataset/Test/1/12867_idx5_x1251_y1151_class1.png', '/content/Dataset/Test/1/10258_idx5_x1001_y1051_class1.png', '/content/Dataset/Test/1/12881_idx5_x551_y1251_class1.png', '/content/Dataset/Test/1/10273_idx5_x2001_y1901_class1.png', '/content/Dataset/Test/1/9262_idx5_x301_y1051_class1.png', '/content/Dataset/Test/1/16568_idx5_x2101_y751_class1.png', '/content/Dataset/Test/1/10299_idx5_x351_y1651_class1.png', '/content/Dataset/Test/1/9267_idx5_x1951_y1101_class1.png', '/content/Dataset/Test/1/9346_idx5_x1951_y2401_class1.png', '/content/Dataset/Test/1/12929_idx5_x1151_y701_class1.png', '/content/Dataset/Test/1/12818_idx5_x2651_y1401_class1.png', '/content/Dataset/Test/1/8975_idx5_x1301_y1751_class1.png', '/content/Dataset/Test/1/12883_idx5_x901_y351_class1.png', '/content/Dataset/Test/1/15472_idx5_x1501_y1351_class1.png', '/content/Dataset/Test/1/14192_idx5_x701_y1451_class1.png', '/content/Dataset/Test/1/14304_idx5_x1651_y701_class1.png', '/content/Dataset/Test/1/9124_idx5_x1001_y1001_class1.png', '/content/Dataset/Test/1/12947_idx5_x1751_y1951_class1.png', '/content/Dataset/Test/1/10273_idx5_x2351_y1501_class1.png', '/content/Dataset/Test/1/9023_idx5_x2051_y1951_class1.png', '/content/Dataset/Test/1/15902_idx5_x2101_y1051_class1.png', '/content/Dataset/Test/1/12951_idx5_x1601_y1951_class1.png', '/content/Dataset/Test/1/10308_idx5_x2101_y751_class1.png', '/content/Dataset/Test/1/10308_idx5_x1001_y1201_class1.png', '/content/Dataset/Test/1/12930_idx5_x2151_y2151_class1.png', '/content/Dataset/Test/1/13613_idx5_x2651_y1351_class1.png', '/content/Dataset/Test/1/9023_idx5_x2101_y1751_class1.png', '/content/Dataset/Test/1/8980_idx5_x1101_y1351_class1.png', '/content/Dataset/Test/1/9081_idx5_x2851_y1101_class1.png', '/content/Dataset/Test/1/13616_idx5_x1851_y951_class1.png', '/content/Dataset/Test/1/13694_idx5_x1651_y1801_class1.png', '/content/Dataset/Test/1/9176_idx5_x1851_y2051_class1.png', '/content/Dataset/Test/1/14155_idx5_x1851_y1451_class1.png', '/content/Dataset/Test/1/9041_idx5_x2001_y2001_class1.png', '/content/Dataset/Test/1/12751_idx5_x751_y2401_class1.png', '/content/Dataset/Test/1/12882_idx5_x1301_y401_class1.png', '/content/Dataset/Test/1/16570_idx5_x2551_y1051_class1.png', '/content/Dataset/Test/1/16165_idx5_x2151_y1101_class1.png', '/content/Dataset/Test/1/15510_idx5_x2601_y1401_class1.png', '/content/Dataset/Test/1/10282_idx5_x1501_y1501_class1.png', '/content/Dataset/Test/1/16554_idx5_x1001_y1201_class1.png', '/content/Dataset/Test/1/9077_idx5_x851_y1101_class1.png', '/content/Dataset/Test/1/9041_idx5_x2451_y1051_class1.png', '/content/Dataset/Test/1/10286_idx5_x1301_y701_class1.png', '/content/Dataset/Test/1/14081_idx5_x2601_y151_class1.png', '/content/Dataset/Test/1/12884_idx5_x1351_y601_class1.png', '/content/Dataset/Test/1/12894_idx5_x1151_y1351_class1.png', ' ...
# images_list_0: ['/content/Dataset/Test/0/10305_idx5_x1501_y1101_class0.png', '/content/Dataset/Test/0/14321_idx5_x1051_y801_class0.png', '/content/Dataset/Test/0/12892_idx5_x601_y1051_class0.png', '/content/Dataset/Test/0/13404_idx5_x1501_y2101_class0.png', '/content/Dataset/Test/0/9023_idx5_x151_y1001_class0.png', '/content/Dataset/Test/0/12826_idx5_x601_y1401_class0.png', '/content/Dataset/Test/0/9123_idx5_x651_y1801_class0.png', '/content/Dataset/Test/0/8975_idx5_x1451_y2501_class0.png', '/content/Dataset/Test/0/10291_idx5_x2901_y701_class0.png', '/content/Dataset/Test/0/12897_idx5_x2601_y1601_class0.png', '/content/Dataset/Test/0/13404_idx5_x1101_y2901_class0.png', '/content/Dataset/Test/0/12908_idx5_x1351_y1501_class0.png', '/content/Dataset/Test/0/13402_idx5_x2851_y1901_class0.png', '/content/Dataset/Test/0/10290_idx5_x1701_y1501_class0.png', '/content/Dataset/Test/0/15516_idx5_x1051_y851_class0.png', '/content/Dataset/Test/0/10302_idx5_x2701_y401_class0.png', '/content/Dataset/Test/0/10293_idx5_x1101_y1151_class0.png', '/content/Dataset/Test/0/9135_idx5_x501_y151_class0.png', '/content/Dataset/Test/0/15516_idx5_x1651_y1301_class0.png', '/content/Dataset/Test/0/12900_idx5_x2701_y1401_class0.png', '/content/Dataset/Test/0/10305_idx5_x2201_y1301_class0.png', '/content/Dataset/Test/0/12878_idx5_x2101_y2001_class0.png', '/content/Dataset/Test/0/9036_idx5_x3051_y751_class0.png', '/content/Dataset/Test/0/12884_idx5_x1801_y1301_class0.png', '/content/Dataset/Test/0/8975_idx5_x251_y851_class0.png', '/content/Dataset/Test/0/9290_idx5_x301_y1401_class0.png', '/content/Dataset/Test/0/9036_idx5_x3401_y951_class0.png', '/content/Dataset/Test/0/12909_idx5_x1751_y901_class0.png', '/content/Dataset/Test/0/9381_idx5_x2451_y2151_class0.png', '/content/Dataset/Test/0/9266_idx5_x1601_y51_class0.png', '/content/Dataset/Test/0/13916_idx5_x751_y601_class0.png', '/content/Dataset/Test/0/9323_idx5_x851_y2301_class0.png', '/content/Dataset/Test/0/14155_idx5_x2301_y2101_class0.png', '/content/Dataset/Test/0/9266_idx5_x3101_y1101_class0.png', '/content/Dataset/Test/0/15632_idx5_x2001_y1501_class0.png', '/content/Dataset/Test/0/9323_idx5_x1951_y1651_class0.png', '/content/Dataset/Test/0/12949_idx5_x1851_y1651_class0.png', '/content/Dataset/Test/0/13458_idx5_x151_y1001_class0.png', '/content/Dataset/Test/0/13459_idx5_x101_y1001_class0.png', '/content/Dataset/Test/0/13400_idx5_x3351_y1151_class0.png', '/content/Dataset/Test/0/12954_idx5_x1851_y2701_class0.png', '/content/Dataset/Test/0/9259_idx5_x1551_y2351_class0.png', '/content/Dataset/Test/0/13400_idx5_x2301_y501_class0.png', '/content/Dataset/Test/0/13693_idx5_x3201_y1901_class0.png', '/content/Dataset/Test/0/9266_idx5_x1201_y801_class0.png', '/content/Dataset/Test/0/8984_idx5_x1451_y1651_class0.png', '/content/Dataset/Test/0/8956_idx5_x301_y501_class0.png', '/content/Dataset/Test/0/9259_idx5_x2351_y1501_class0.png', '/content/Dataset/Test/0/13400_idx5_x2451_y2351_class0.png', '/content/Dataset/Test/0/10259_idx5_x1851_y1151_class0.png', '/content/Dataset/Test/0/12906_idx5_x501_y751_class0.png', '/content/Dataset/Test/0/8864_idx5_x3151_y1101_class0.png', '/content/Dataset/Test/0/13401_idx5_x1001_y1301_class0.png', '/content/Dataset/Test/0/12821_idx5_x2401_y501_class0.png', '/content/Dataset/Test/0/9254_idx5_x3351_y1051_class0.png', '/content/Dataset/Test/0/12821_idx5_x1151_y101_class0.png', '/content/Dataset/Test/0/13022_idx5_x1751_y1101_class0.png', '/content/Dataset/Test/0/12898_idx5_x1701_y251_class0.png', '/content/Dataset/Test/0/8913_idx5_x2001_y901_class0.png', '/content/Dataset/Test/0/9083_idx5_x401_y301_class0.png', '/content/Dataset/Test/0/10293_idx5_x1751_y1651_class0.png', '/content/Dataset/Test/0/14154_idx5_x801_y351_class0.png', '/content/Dataset/Test/0/13693_idx5_x451_y1851_class0.png', '/content/Dataset/Test/0/14210_idx5_x1001_y1901_class0.png', '/content/Dataset/Test/0/10259_idx5_x51_y951_class0.png', '/content/Dataset/Test/0/13459_idx5_x2501_y851_class0.png', '/content/Dataset/Test ...
# images_path_1: /content/Dataset/Validate/1/
# images_path_0: /content/Dataset/Validate/0/
#
# images_list_1: ['/content/Dataset/Validate/1/9081_idx5_x2801_y1751_class1.png', '/content/Dataset/Validate/1/8916_idx5_x401_y951_class1.png', '/content/Dataset/Validate/1/10299_idx5_x1701_y1151_class1.png', '/content/Dataset/Validate/1/15634_idx5_x2251_y1101_class1.png', '/content/Dataset/Validate/1/14191_idx5_x1801_y1501_class1.png', '/content/Dataset/Validate/1/9267_idx5_x1801_y651_class1.png', '/content/Dataset/Validate/1/9291_idx5_x2401_y1551_class1.png', '/content/Dataset/Validate/1/9126_idx5_x2251_y1901_class1.png', '/content/Dataset/Validate/1/13023_idx5_x1101_y951_class1.png', '/content/Dataset/Validate/1/12242_idx5_x2001_y1001_class1.png', '/content/Dataset/Validate/1/15633_idx5_x1051_y801_class1.png', '/content/Dataset/Validate/1/13694_idx5_x1451_y1751_class1.png', '/content/Dataset/Validate/1/10306_idx5_x651_y1101_class1.png', '/content/Dataset/Validate/1/10273_idx5_x1501_y2201_class1.png', '/content/Dataset/Validate/1/12947_idx5_x1851_y2101_class1.png', '/content/Dataset/Validate/1/14157_idx5_x1551_y1101_class1.png', '/content/Dataset/Validate/1/16165_idx5_x1701_y1051_class1.png', '/content/Dataset/Validate/1/9123_idx5_x1751_y1551_class1.png', '/content/Dataset/Validate/1/13106_idx5_x1151_y2101_class1.png', '/content/Dataset/Validate/1/12751_idx5_x1801_y1201_class1.png', '/content/Dataset/Validate/1/13459_idx5_x1001_y351_class1.png', '/content/Dataset/Validate/1/10258_idx5_x1101_y901_class1.png', '/content/Dataset/Validate/1/12820_idx5_x1901_y651_class1.png', '/content/Dataset/Validate/1/10275_idx5_x1851_y1051_class1.png', '/content/Dataset/Validate/1/9125_idx5_x1151_y1751_class1.png', '/content/Dataset/Validate/1/12895_idx5_x1251_y1251_class1.png', '/content/Dataset/Validate/1/14306_idx5_x2251_y1351_class1.png', '/content/Dataset/Validate/1/9256_idx5_x2001_y1551_class1.png', '/content/Dataset/Validate/1/13025_idx5_x1901_y951_class1.png', '/content/Dataset/Validate/1/9323_idx5_x951_y1551_class1.png', '/content/Dataset/Validate/1/13616_idx5_x1601_y1401_class1.png', '/content/Dataset/Validate/1/16553_idx5_x951_y1301_class1.png', '/content/Dataset/Validate/1/12947_idx5_x1451_y1851_class1.png', '/content/Dataset/Validate/1/14082_idx5_x1601_y1951_class1.png', '/content/Dataset/Validate/1/12934_idx5_x2651_y2351_class1.png', '/content/Dataset/Validate/1/9257_idx5_x1751_y701_class1.png', '/content/Dataset/Validate/1/12949_idx5_x1451_y1151_class1.png', '/content/Dataset/Validate/1/12884_idx5_x1701_y1001_class1.png', '/content/Dataset/Validate/1/12947_idx5_x1201_y2051_class1.png', '/content/Dataset/Validate/1/14155_idx5_x2601_y551_class1.png', '/content/Dataset/Validate/1/13617_idx5_x1051_y251_class1.png', '/content/Dataset/Validate/1/14155_idx5_x1801_y1151_class1.png', '/content/Dataset/Validate/1/9077_idx5_x2401_y801_class1.png', '/content/Dataset/Validate/1/12867_idx5_x1101_y1451_class1.png', '/content/Dataset/Validate/1/14213_idx5_x1751_y901_class1.png', '/content/Dataset/Validate/1/12817_idx5_x1301_y1401_class1.png', '/content/Dataset/Validate/1/12242_idx5_x2051_y751_class1.png', '/content/Dataset/Validate/1/12751_idx5_x2051_y2451_class1.png', '/content/Dataset/Validate/1/10302_idx5_x951_y1951_class1.png', '/content/Dataset/Validate/1/9081_idx5_x2501_y1251_class1.png', '/content/Dataset/Validate/1/14154_idx5_x2501_y1401_class1.png', '/content/Dataset/Validate/1/9029_idx5_x2001_y951_class1.png', '/content/Dataset/Validate/1/12867_idx5_x1051_y1401_class1.png', '/content/Dataset/Validate/1/14304_idx5_x1001_y401_class1.png', '/content/Dataset/Validate/1/12908_idx5_x2351_y801_class1.png', '/content/Dataset/Validate/1/15510_idx5_x2051_y2151_class1.png', '/content/Dataset/Validate/1/15840_idx5_x301_y851_class1.png', '/content/Dataset/Validate/1/10291_idx5_x1551_y951_class1.png', '/content/Dataset/Validate/1/10276_idx5_x701_y551_class1.png', '/content/Dataset/Validate/1/10269_idx5_x2201_y1001_class1.png', '/content/Dataset/Validate/1/10299_idx5_x2301_y1351_class1.png', '/content/Dataset/Validate/1/12895_idx5_x1651_y2601_class1. ...
# images_list_0: ['/content/Dataset/Validate/0/10277_idx5_x3201_y951_class0.png', '/content/Dataset/Validate/0/16568_idx5_x451_y1151_class0.png', '/content/Dataset/Validate/0/9177_idx5_x2501_y801_class0.png', '/content/Dataset/Validate/0/12890_idx5_x1601_y2151_class0.png', '/content/Dataset/Validate/0/12878_idx5_x2301_y951_class0.png', '/content/Dataset/Validate/0/9325_idx5_x3501_y1151_class0.png', '/content/Dataset/Validate/0/10282_idx5_x2751_y1051_class0.png', '/content/Dataset/Validate/0/10288_idx5_x1151_y2051_class0.png', '/content/Dataset/Validate/0/9265_idx5_x1401_y1551_class0.png', '/content/Dataset/Validate/0/8917_idx5_x1151_y1201_class0.png', '/content/Dataset/Validate/0/9023_idx5_x701_y601_class0.png', '/content/Dataset/Validate/0/9037_idx5_x751_y501_class0.png', '/content/Dataset/Validate/0/8918_idx5_x1951_y1901_class0.png', '/content/Dataset/Validate/0/8974_idx5_x1301_y801_class0.png', '/content/Dataset/Validate/0/12884_idx5_x1351_y151_class0.png', '/content/Dataset/Validate/0/9037_idx5_x2151_y1301_class0.png', '/content/Dataset/Validate/0/15839_idx5_x351_y551_class0.png', '/content/Dataset/Validate/0/8984_idx5_x3001_y251_class0.png', '/content/Dataset/Validate/0/16551_idx5_x1701_y1251_class0.png', '/content/Dataset/Validate/0/12626_idx5_x2601_y2251_class0.png', '/content/Dataset/Validate/0/9075_idx5_x1201_y2101_class0.png', '/content/Dataset/Validate/0/10269_idx5_x1251_y1851_class0.png', '/content/Dataset/Validate/0/12870_idx5_x1451_y2151_class0.png', '/content/Dataset/Validate/0/12871_idx5_x1201_y1051_class0.png', '/content/Dataset/Validate/0/14191_idx5_x2051_y801_class0.png', '/content/Dataset/Validate/0/12894_idx5_x701_y2151_class0.png', '/content/Dataset/Validate/0/8867_idx5_x1601_y1551_class0.png', '/content/Dataset/Validate/0/9073_idx5_x1101_y1051_class0.png', '/content/Dataset/Validate/0/10282_idx5_x1151_y1751_class0.png', '/content/Dataset/Validate/0/16085_idx5_x1351_y2751_class0.png', '/content/Dataset/Validate/0/12750_idx5_x851_y1201_class0.png', '/content/Dataset/Validate/0/10301_idx5_x2101_y1351_class0.png', '/content/Dataset/Validate/0/9382_idx5_x201_y2651_class0.png', '/content/Dataset/Validate/0/12895_idx5_x2851_y351_class0.png', '/content/Dataset/Validate/0/15902_idx5_x901_y1251_class0.png', '/content/Dataset/Validate/0/12877_idx5_x1651_y601_class0.png', '/content/Dataset/Validate/0/16085_idx5_x2001_y2501_class0.png', '/content/Dataset/Validate/0/14192_idx5_x2701_y601_class0.png', '/content/Dataset/Validate/0/15902_idx5_x1201_y901_class0.png', '/content/Dataset/Validate/0/12931_idx5_x1901_y2151_class0.png', '/content/Dataset/Validate/0/9266_idx5_x1451_y801_class0.png', '/content/Dataset/Validate/0/10300_idx5_x1551_y1101_class0.png', '/content/Dataset/Validate/0/9173_idx5_x2801_y851_class0.png', '/content/Dataset/Validate/0/10308_idx5_x2651_y1051_class0.png', '/content/Dataset/Validate/0/13462_idx5_x2601_y1801_class0.png', '/content/Dataset/Validate/0/8913_idx5_x2151_y851_class0.png', '/content/Dataset/Validate/0/12870_idx5_x501_y2051_class0.png', '/content/Dataset/Validate/0/14190_idx5_x651_y1301_class0.png', '/content/Dataset/Validate/0/9320_idx5_x3101_y1551_class0.png', '/content/Dataset/Validate/0/9078_idx5_x2251_y1401_class0.png', '/content/Dataset/Validate/0/13021_idx5_x3001_y851_class0.png', '/content/Dataset/Validate/0/12910_idx5_x3301_y1001_class0.png', '/content/Dataset/Validate/0/14157_idx5_x351_y2401_class0.png', '/content/Dataset/Validate/0/9324_idx5_x2651_y1351_class0.png', '/content/Dataset/Validate/0/10288_idx5_x1451_y1501_class0.png', '/content/Dataset/Validate/0/12868_idx5_x2451_y51_class0.png', '/content/Dataset/Validate/0/9227_idx5_x1501_y2101_class0.png', '/content/Dataset/Validate/0/12869_idx5_x1301_y1201_class0.png', '/content/Dataset/Validate/0/9175_idx5_x3301_y301_class0.png', '/content/Dataset/Validate/0/9256_idx5_x1051_y1501_class0.png', '/content/Dataset/Validate/0/13694_idx5_x1551_y2801_class0.png', '/content/Dataset/Validate/0/9181_idx5_x2401_y2301_class0.png', '/content/ ...
#
# train_1_images_list[0] /content/Dataset/Train/1/10269_idx5_x1351_y801_class1.png
# train_0_images_list[0] /content/Dataset/Train/0/9256_idx5_x1901_y51_class0.png

# %%
len(train_1_images_list + train_0_images_list + test_1_images_list + test_0_images_list + val_1_images_list + val_0_images_list)
# Out:
# 1200

# %%
len(train_1_images_list), len(train_0_images_list), len(test_1_images_list), len(test_0_images_list), len(val_1_images_list), len(val_0_images_list)
# Out:
# (400, 400, 100, 100, 100, 100)

# %% [markdown]
# ## Display the first 6 images for each class
# : IDC Malignant (1) vs. IDC Benign (0)

# %%
IMG_SIZE = 50

# %%
def display_images(subclass, class_name):
  fig, axes = plt.subplots(nrows=1, ncols=6, figsize=(17,6))
  for idx, ax in enumerate(axes.flat):
    img = io.imread(subclass[idx])
    img = cv.resize(img, (IMG_SIZE, IMG_SIZE))    # resize an image from 50 by 50 to 512 by 512
    ax.imshow(img)
    ax.set_title(class_name)
    ax.set_xticks([])       # remove xticks passing an empty array
    ax.set_yticks([])       # remove yticks passing an empty array
  fig.tight_layout() 
  plt.show() 

# display_images(train_1_images_list, 'IDC Malignant (1)')
# display_images(train_0_images_list, ' IDC Benign (0)')

display_images(train_1_images_list, '')
display_images(train_0_images_list, '')

# %%
test_img = load_img(train_1_images_list[0], color_mode ="grayscale")
test_img_arry = img_to_array(test_img)/255                                 # normalize
print(type(test_img))
print(test_img.format)
print(test_img.mode)
print(test_img.size)
print(test_img.getbands())
print(test_img_arry.shape)
print("****")
test_img1 = load_img(train_1_images_list[0])
test_img1_arry = img_to_array(test_img1)
print(test_img1_arry.shape)
print(test_img1.getbands())
array_to_img(test_img_arry)
# Out:
# <class 'PIL.Image.Image'>
# None
# L
# (50, 50)
# ('L',)
# (50, 50, 1)
# ****
# (50, 50, 3)
# ('R', 'G', 'B')
# <PIL.Image.Image image mode=L size=50x50 at 0x7FF36776D1F0>

# %% [markdown]
# # Filter Out Odd Images
# - Exclude images that are not **50 by 50**
# - Exclude images with no **.png** extension

# %%
odd_images = []
def extract_odd_images(file_list, IMG_SIZE = 50):
    for file_name in file_list:
        test_img = load_img(file_name, color_mode ="grayscale")
        test_img_arry = img_to_array(test_img)
        if test_img_arry.shape[0] != IMG_SIZE or test_img_arry.shape[1] != IMG_SIZE:
            odd_images.append(file_name)

# %%
extract_odd_images(train_1_images_list + train_0_images_list + test_1_images_list + test_0_images_list + val_1_images_list + val_0_images_list)

# %%
odd_images
# Out:
# ['/content/Dataset/Train/0/12954_idx5_x1651_y2951_class0.png',
#  '/content/Dataset/Train/0/13106_idx5_x1_y2951_class0.png',
#  '/content/Dataset/Train/0/9347_idx5_x2101_y801_class0.png',
#  '/content/Dataset/Test/0/13404_idx5_x1101_y2901_class0.png',
#  '/content/Dataset/Validate/0/12931_idx5_x1901_y2151_class0.png',
#  '/content/Dataset/Validate/0/13694_idx5_x1551_y2801_class0.png',
#  '/content/Dataset/Validate/0/9320_idx5_x801_y2951_class0.png']

# %%
import cv2 as cv
import skimage.io as io

def display_images(subclass):
  fig, axes = plt.subplots(nrows=1, ncols=7, figsize=(20,8))
  for idx, ax in enumerate(axes.flat):
    image_wo_path = os.path.basename(subclass[idx])
    subtitle = 'Class ' + image_wo_path.rsplit('.')[0][-1] + ': ' + subclass[idx].split('/')[3]
    img = io.imread(subclass[idx])
    ax.imshow(img)
    # ax.axis('off')
    ax.set_title(subtitle, size=14)   
  fig.tight_layout() 
  plt.show() 

print();display_images(odd_images)

# %%
train_0_images_list[:5]
# Out:
# ['/content/Dataset/Train/0/9256_idx5_x1901_y51_class0.png',
#  '/content/Dataset/Train/0/9073_idx5_x2851_y1251_class0.png',
#  '/content/Dataset/Train/0/10292_idx5_x3451_y1151_class0.png',
#  '/content/Dataset/Train/0/10302_idx5_x501_y1701_class0.png',
#  '/content/Dataset/Train/0/12879_idx5_x201_y301_class0.png']

# %%
train_1_images_list[0].split("/")[-1], train_1_images_list[0][:train_1_images_list[0].rfind("/") + 1]
# Out:
# ('10269_idx5_x1351_y801_class1.png', '/content/Dataset/Train/1/')

# %%
# delete a full folder including all its files and subfolders
# !rm -rf processed_images/

# %% [markdown]
# # Create a New Directory Path to Store Processed Images

# %%
root_dir = 'processed_images'

os.makedirs(f'{root_dir}', exist_ok = True)
for dir in ['train', 'val', 'test']:
    for sub_dir in ['1', '0']:
        os.makedirs(f'{root_dir}/{dir}/{sub_dir}', exist_ok=True)

# %% [markdown]
# # Image Augmentation on Training Dataset
# - Convert color to gray scale
# - Flip: Horizontal and Vertical
# - Rotate 90 degree

# %%
# https://towardsdatascience.com/complete-image-augmentation-in-opencv-31a6b02694f5

from google.colab.patches import cv2_imshow
target_size=(150,150)

# original: 50x50 rgb 
org_img = load_img(train_0_images_list[2], color_mode ="rgb", target_size=target_size)
org_img_arry = img_to_array(org_img)
print('shape org_img_arry RGB: ',org_img_arry.shape)
print("  Original:50x50(RGB)");print()
cv2_imshow(org_img_arry)

# original: 50x50 grayscale 
test_img = load_img(train_0_images_list[2], color_mode ="grayscale", target_size=target_size)
test_img_arry = img_to_array(test_img)
print('shape gray not norm RGB: ',test_img_arry.shape)
print();print(" Not normalized-Original:50x50(Gray)");print()
cv2_imshow(test_img_arry)

#  normalized gray scale
norm_test_img_arry = cv2.normalize(test_img_arry, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
print('shape gray norm RGB: ',norm_test_img_arry.shape)
print();print('Normalized-gray');print()
cv2_imshow(norm_test_img_arry)
# print('norm1-gray:\n', norm_test_img_arry)

# brightness
bright_img_gs = tf.image.adjust_brightness(norm_test_img_arry, delta=10)
bright_img_gs = img_to_array(bright_img_gs)
print();print(" Brightness:0.1,0.3");print()
cv2_imshow(bright_img_gs)

# contrast
contrast_img_gs = tf.image.adjust_contrast(test_img_arry, contrast_factor=3)
contrast_img_gs = img_to_array(contrast_img_gs)
print();print("    Contrast:1,3");print()
cv2_imshow(contrast_img_gs)

# horizontal flip
hflip_img_gs = cv2.flip(norm_test_img_arry, 1)
print();print("  Horizontal Flip");print()
cv2_imshow(hflip_img_gs)

# vertical flip
vflip_img_gs = cv2.flip(norm_test_img_arry, 0)
print();print("   Vertical Flip");print()
cv2_imshow(vflip_img_gs)

# random rotate 
angle = int(random.uniform(-90, 90))
hr, wr = norm_test_img_arry.shape[:2]
M = cv2.getRotationMatrix2D((int(wr/2), int(hr/2)), angle, 1)
rotated_img_gs = cv2.warpAffine(norm_test_img_arry, M, (wr, hr))
rotated_img_gs = img_to_array(rotated_img_gs)
print();print("    RandomRotate");print()
cv2_imshow(rotated_img_gs)

# rotate 90 degree ccw
out=cv2.transpose(norm_test_img_arry)
out=cv2.flip(out,flipCode=0)
rotated_img_gs = img_to_array(out)
print();print("    Rotate 90:CCW");print()
cv2_imshow(out)

# rotate 90 degree cw
out=cv2.transpose(norm_test_img_arry)
out=cv2.flip(out,flipCode=1)
rotated_img_gs = img_to_array(out)/255        # normalize it after augment the image
# print('rotated_img_gs',rotated_img_gs)
print();print("     Rotate 90:CW");print()
cv2_imshow(out)

# fill mode = 'nearest'
# ratio = random.uniform(-ratio, ratio)
# def fill_mode(ratio, img):
#   fm_ratio = random.uniform(-ratio, ratio)
#   h, w = img.shape[:2]
#   to_shift = int(w*fm_ratio)
#   if fm_ratio > 0:
#       img = img[:, :w-to_shift, :]
#       nearest_img_gs = cv2.copyMakeBorder(img, 0, 0, to_shift, 0, cv2.BORDER_REPLICATE)
#       # constant_img_gs= cv2.copyMakeBorder(img, 0, 0, to_shift, 0, cv2.BORDER_CONSTANT,value=(255, 0, 0))
#   if fm_ratio < 0:
#       img = img[:, -1*to_shift:, :]
#       nearest_img_gs = cv2.copyMakeBorder(img, 0, 0, 0, -1*to_shift, cv2.BORDER_REPLICATE)
#       # constant_img_gs= cv2.copyMakeBorder(img, 0, 0, 0, -1*to_shift, cv2.BORDER_CONSTANT,value=(255, 0, 0))  
#   return nearest_img_gs

# # test_img = load_img(train_1_images_list[5], color_mode ="grayscale", target_size=target_size)
# # test_img_arry = img_to_array(test_img)
# # nearest_img_gs = fill_mode(0.8, contrast_img_gs)
# nearest_img_gs = fill_mode(0.8, np.reshape(norm_test_img_arry, [axis=1])) 
# print(np.reshape(a, [2, 3, 4]))
# nearest_img_gs = img_to_array(nearest_img_gs)
# print();print("   FillMode:Nearest");print()
# print(np.expand_dims(norm_test_img_arry, axis=1).shape)
# cv2_imshow(nearest_img_gs)

# # Random ZoomIn
# def zoom_in(ratio, img):
#   z_ratio = random.uniform(ratio, 1)
#   h, w = img.shape[:2]
#   h_taken = int(z_ratio*h)
#   w_taken = int(z_ratio*w)
#   h_start = random.randint(0, h-h_taken)
#   w_start = random.randint(0, w-w_taken)
#   img = img[h_start:h_start+h_taken, w_start:w_start+w_taken, :]
#   zoomed_img_gs = cv2.resize(img, (h, w), cv2.INTER_CUBIC)  
#   return zoomed_img_gs
# zoomed_img_gs = zoom_in(0.6, contrast_img_gs)
# zoomed_img_gs = img_to_array(zoomed_img_gs)
# print('Zoom-In', zoomed_img_gs)
# print();print("   Random Zoom-In");print()
# cv2_imshow(zoomed_img_gs)

# shift the image 5 pixels to the left and 10 pixels down
M = np.float32([[1, 0, -10], [0, 1, 20]])
shifted_ld_gs = cv2.warpAffine(norm_test_img_arry, M, (norm_test_img_arry.shape[1], norm_test_img_arry.shape[0]))
print();print(" RandomShift:LeftDown");print()
cv2_imshow(shifted_ld_gs)

# shift the image 5 pixels to the right and 10 pixels up
M = np.float32([[1, 0, 17], [0, 1, -8]])
shifted_ru_gs = cv2.warpAffine(norm_test_img_arry, M, (norm_test_img_arry.shape[1], norm_test_img_arry.shape[0]))
print();print(" RandomShift:RightUp");print()
cv2_imshow(shifted_ru_gs)
# Out:
# shape org_img_arry RGB:  (150, 150, 3)
#   Original:50x50(RGB)
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FF3665F65E0>
# shape gray not norm RGB:  (150, 150, 1)
#
#  Not normalized-Original:50x50(Gray)
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FF3665F6E50>
# shape gray norm RGB:  (150, 150)
#
# Normalized-gray
# <PIL.Image.Image image mode=L size=150x150 at 0x7FF3665F6EB0>
#  Brightness:0.1,0.3
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FF3665F6520>
#     Contrast:1,3
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FF3665F6700>
#   Horizontal Flip
# <PIL.Image.Image image mode=L size=150x150 at 0x7FF36776DB80>
#    Vertical Flip
# <PIL.Image.Image image mode=L size=150x150 at 0x7FF3665F6DC0>
#     RandomRotate
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FF3667A2FD0>
#     Rotate 90:CCW
# <PIL.Image.Image image mode=L size=150x150 at 0x7FF3665F6070>
#      Rotate 90:CW
# <PIL.Image.Image image mode=L size=150x150 at 0x7FF3667A2FD0>
#  RandomShift:LeftDown
# <PIL.Image.Image image mode=L size=150x150 at 0x7FF3667A2FD0>
#  RandomShift:RightUp
# <PIL.Image.Image image mode=L size=150x150 at 0x7FF3667A2FD0>

# %%
# original: 50x50 grayscale 
test_img = load_img(train_0_images_list[2], color_mode ="grayscale", target_size=target_size)
test_img_arry = img_to_array(test_img)
print();print(" Not normalized-Original:50x50(Gray)");print()
cv2_imshow(test_img_arry)

norm1 = cv2.normalize(test_img_arry, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
print();print('Normalized-gray');print()
cv2_imshow(norm1)
print('norm1-gray:\n', norm1)

# original: 50x50 rgb 
org_img = load_img(train_0_images_list[2], color_mode ="rgb", target_size=target_size)
org_img_arry = img_to_array(org_img)
print("  \nNot normalized-Original:50x50(RGB)");print()
cv2_imshow(org_img_arry)

print();print('Normalized-rgb');print()
# norm = cv2.normalize(test_img_arry, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
norm1 = cv2.normalize(org_img_arry, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
cv2_imshow(norm1)
# Out:
#  Not normalized-Original:50x50(Gray)
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FF367B38550>
# Normalized-gray
# <PIL.Image.Image image mode=L size=150x150 at 0x7FF37163FD90>
# norm1-gray:
#  [[222.44681 222.44681 222.44681 ... 246.8617  246.8617  246.8617 ]
#  [222.44681 222.44681 222.44681 ... 246.8617  246.8617  246.8617 ]
#  [222.44681 222.44681 222.44681 ... 246.8617  246.8617  246.8617 ]
#  ...
#  [207.5266  207.5266  207.5266  ... 250.93085 250.93085 250.93085]
#  [207.5266  207.5266  207.5266  ... 250.93085 250.93085 250.93085]
#  [207.5266  207.5266  207.5266  ... 250.93085 250.93085 250.93085]]
#
# Not normalized-Original:50x50(RGB)
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FF36E9210A0>
# Normalized-rgb
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FF3665E9F10>

# %%
# resized = cv2.resize(test_img_arry, (224, 224), interpolation = cv2.INTER_AREA) 
# print('Resized Dimensions : ',resized.shape) 
# cv2_imshow(resized)

# %% [markdown]
# # Normalize images with range 0 to 1
# Images are already normalized in **ImageDataGenerator by rescaling 1.0/255** thus we DO NOT NEED to normalize images in this **create_gs_files()** function.

# %%
# def create_gs_files(file_list, dest_dir, ind):
def create_gs_files(file_list, dest_dir, ind, brightness_delta=0.3, contrast_factor=3, angle=90, right=7, up=-10, left=-7, down=10):
# def create_gs_files(file_list, dest_dir, ind, brightness_delta=0.3, contrast_factor=3, angle=90):
  # create_gs_files(train_1_images_list, tgt_train_1_image_path, 1, 0.3, 3, 45, 7, -10, -7, 10)
  # print(file_list, dest_dir, ind)
  lst_train_1_gs, lst_train_0_gs = [], []
  lst_val_1_gs, lst_val_0_gs = [], []
  lst_test_1_gs, lst_test_0_gs = [], []

  file_extension = '.png'
  # norm_pixel = 255.0
  for image_file in file_list:
      #print(image_file)
      if image_file[0] == '.' or image_file in odd_images:                                     # if image_file = .DS_Store or an odd image then ignore
          continue
      img_gs = load_img(image_file, color_mode = "grayscale")                                     # convert images from colorscale to grayscale
      # img_array_gs = img_to_array(img_gs)/255               
      img_array_gs = img_to_array(img_gs)                     # Not normalizing the pixels
      # img_array_gs = cv2.normalize(img_array_gs, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)   # Normalizing the pixels

      # print('==================')     
      # print('original non-normalized')
      # print(cv2_imshow(img_array_gs))      
      # print('original normalized')
      # print(cv2_imshow(img_array_gs)) 

      file_name = image_file.split("/")[-1]                                          
      save_img(dest_dir + file_name.split(".")[0] + '_gs' + file_extension, img_array_gs)     # CORRECT: pass 'img_array_gs' instead of 'img_array_gs'. otherwise getting an error

      if ind == 1:
          # insert raw training images in gray scale
          lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_gs' + file_extension)

          # adjust brightness
          bright_img_gs = tf.image.adjust_brightness(img_array_gs, delta=brightness_delta)
          img_array_bright_gs = img_to_array(bright_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_bright_gs' + file_extension, img_array_bright_gs)
          lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_bright_gs' + file_extension)

          # print();print(" Brightness");print()
          # cv2_imshow(img_array_bright_gs)
          
          # adjust contrast
          contrast_img_gs = tf.image.adjust_contrast(img_array_gs, contrast_factor=contrast_factor)
          img_array_contrast_gs = img_to_array(contrast_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_contrast_gs' + file_extension, img_array_contrast_gs)
          lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_contrast_gs' + file_extension)

          # print();print(" contrast");print()
          # cv2_imshow(img_array_contrast_gs)

          # horizontal flip
          hflip_img_gs = cv2.flip(img_array_gs, 1)
          img_array_hflip_gs = img_to_array(hflip_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_hflip_gs' + file_extension, img_array_hflip_gs)
          lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_hflip_gs' + file_extension)

          # print();print(" hvip");print()
          # cv2_imshow(img_array_hflip_gs)

          # vertical flip
          vflip_img_gs = cv2.flip(img_array_gs, 0)
          img_array_vflip_gs = img_to_array(vflip_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_vflip_gs' + file_extension, img_array_vflip_gs)
          lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_vflip_gs' + file_extension)

          # print();print(" vvip");print()
          # cv2_imshow(img_array_vflip_gs)

          # random rotate 
          rotate = int(random.uniform(-angle, angle))
          # print('rotate ind=1', rotate)
          h, w = img_array_gs.shape[:2]
          M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), rotate, 1)
          rotated_img_gs = cv2.warpAffine(img_array_gs, M, (w, h))
          img_array_rotated_gs = img_to_array(rotated_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_' + str(rotate) + 'rotated_gs' + file_extension, img_array_rotated_gs)
          lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_' + str(rotate) + 'rotated_gs' + file_extension)

          # print();print(" randome rotate");print()
          # cv2_imshow(img_array_rotated_gs)

          # rotate 90 degrees counter clockwise (flip around x-axis)
          img_ccw90rot_gs = cv2.transpose(img_array_gs)
          img_ccw90rot_gs = cv2.flip(img_ccw90rot_gs, flipCode = 0)
          rotatedccw90_img_gs = img_to_array(img_ccw90rot_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_ccw90rot_gs' + file_extension, rotatedccw90_img_gs)
          lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_ccw90rot_gs' + file_extension)

          # print();print(" 90ccw");print()
          # cv2_imshow(rotatedccw90_img_gs)

          # rotate 90 degrees clockwise(flip around y-axis)
          img_90rot_gs = cv2.transpose(img_array_gs)
          img_90rot_gs = cv2.flip(img_90rot_gs, flipCode = 1)
          rotated90_img_gs = img_to_array(img_90rot_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_cw90rot_gs' + file_extension, rotated90_img_gs)
          lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_cw90rot_gs' + file_extension)

          # print();print(" 90cw");print()
          # cv2_imshow(rotated90_img_gs)

          # random zoom-in                       
          zoomed_img_gs = zoom_in(0.6, img_array_contrast_gs)
          img_array_zoomed_img_gs = img_to_array(zoomed_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_random_zoom_in_gs' + file_extension, img_array_zoomed_img_gs)
          lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_random_zoom_in_gs' + file_extension)

          # print();print(" zoom in");print()
          # cv2_imshow(img_array_zoomed_img_gs)

          # fill_mode = nearst
          nearest_img_gs = fill_mode(0.8, img_array_contrast_gs)
          img_array_nearest_img_gs = img_to_array(nearest_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_fillmode_nearest_gs' + file_extension, img_array_nearest_img_gs)
          lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_fillmode_nearest_gs' + file_extension)

          # print();print(" fill_mode:nearest");print()
          # cv2_imshow(img_array_nearest_img_gs)

          # shift the image 7 pixels to the right and -10 pixels up
          M = np.float32([[1, 0, right], [0, 1, up]])
          shifted_lu = cv2.warpAffine(img_array_gs, M, (img_array_gs.shape[1], img_array_gs.shape[0]))
          img_array_shifted_ru_gs = img_to_array(shifted_lu)
          save_img(dest_dir + file_name.split(".")[0] + '_shifted_right_up_gs' + file_extension, img_array_shifted_ru_gs)
          lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_shifted_right_up_gs' + file_extension)

          # print();print(" shift right down");print()
          # cv2_imshow(img_array_shifted_ru_gs)

          # # shift the image -7 pixels to the left and 10 pixels down
          M = np.float32([[1, 0, left], [0, 1, down]])
          shifted_rd = cv2.warpAffine(img_array_gs, M, (img_array_gs.shape[1], img_array_gs.shape[0]))
          img_array_shifted_ld_gs = img_to_array(shifted_rd)
          save_img(dest_dir + file_name.split(".")[0] + '_shifted_left_down_gs' + file_extension, img_array_shifted_ld_gs)
          lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_shifted_left_down_gs' + file_extension)

          # print();print(" shift left up");print()
          # cv2_imshow(img_array_shifted_ld_gs)

      elif ind == 2:
          # insert raw training images in gray scale
          lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_gs' + file_extension)

           # print();print('Normalized-gray');print()
          # cv2_imshow(lst_train_0_gs[0])

          # adjust brightness
          bright_img_gs = tf.image.adjust_brightness(img_array_gs, delta=brightness_delta)
          img_array_bright_gs = img_to_array(bright_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_bright_gs' + file_extension, img_array_bright_gs)
          lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_bright_gs' + file_extension)

          # print();print(" Brightness");print()
          # cv2_imshow(img_array_bright_gs)
          
          # adjust contrast
          contrast_img_gs = tf.image.adjust_contrast(img_array_gs, contrast_factor=contrast_factor)
          img_array_contrast_gs = img_to_array(contrast_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_contrast_gs' + file_extension, img_array_contrast_gs)
          lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_contrast_gs' + file_extension)

          # print();print(" contrast");print()
          # cv2_imshow(img_array_contrast_gs)

          # horizontal flip
          hflip_img_gs = cv2.flip(img_array_gs, 1)
          img_array_hflip_gs = img_to_array(hflip_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_hflip_gs' + file_extension, img_array_hflip_gs)
          lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_hflip_gs' + file_extension)

          # print();print(" hvip");print()
          # cv2_imshow(img_array_hflip_gs)

          # vertical flip
          vflip_img_gs = cv2.flip(img_array_gs, 0)
          img_array_vflip_gs = img_to_array(vflip_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_vflip_gs' + file_extension, img_array_vflip_gs)
          lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_vflip_gs' + file_extension)

          # print();print(" vvip");print()
          # cv2_imshow(img_array_vflip_gs)

          # random rotate 
          rotate = int(random.uniform(-angle, angle))
          # print('rotate ind=1', rotate)
          h, w = img_array_gs.shape[:2]
          M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), rotate, 1)
          rotated_img_gs = cv2.warpAffine(img_array_gs, M, (w, h))
          img_array_rotated_gs = img_to_array(rotated_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_' + str(rotate) + 'rotated_gs' + file_extension, img_array_rotated_gs)
          lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_' + str(rotate) + 'rotated_gs' + file_extension)

          # print();print(" randome rotate");print()
          # cv2_imshow(img_array_rotated_gs)

          # rotate 90 degrees counter clockwise (flip around x-axis)
          img_ccw90rot_gs = cv2.transpose(img_array_gs)
          img_ccw90rot_gs = cv2.flip(img_ccw90rot_gs, flipCode = 0)
          rotatedccw90_img_gs = img_to_array(img_ccw90rot_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_ccw90rot_gs' + file_extension, rotatedccw90_img_gs)
          lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_ccw90rot_gs' + file_extension)

          # print();print(" 90ccw");print()
          # cv2_imshow(rotatedccw90_img_gs)

          # rotate 90 degrees clockwise(flip around y-axis)
          img_90rot_gs = cv2.transpose(img_array_gs)
          img_90rot_gs = cv2.flip(img_90rot_gs, flipCode = 1)
          rotated90_img_gs = img_to_array(img_90rot_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_cw90rot_gs' + file_extension, rotated90_img_gs)
          lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_cw90rot_gs' + file_extension)

          # print();print(" 90cw");print()
          # cv2_imshow(rotated90_img_gs)

          # random zoom-in                       
          zoomed_img_gs = zoom_in(0.6, img_array_contrast_gs)
          img_array_zoomed_img_gs = img_to_array(zoomed_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_random_zoom_in_gs' + file_extension, img_array_zoomed_img_gs)
          lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_random_zoom_in_gs' + file_extension)

          # print();print(" zoom in");print()
          # cv2_imshow(img_array_zoomed_img_gs)

          # fill_mode = nearst
          nearest_img_gs = fill_mode(0.8, img_array_contrast_gs)
          img_array_nearest_img_gs = img_to_array(nearest_img_gs)
          save_img(dest_dir + file_name.split(".")[0] + '_fillmode_nearest_gs' + file_extension, img_array_nearest_img_gs)
          lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_fillmode_nearest_gs' + file_extension)

          # print();print(" fill_mode:nearest");print()
          # cv2_imshow(img_array_nearest_img_gs)

          # shift the image 7 pixels to the right and -10 pixels up
          M = np.float32([[1, 0, right], [0, 1, up]])
          shifted_lu = cv2.warpAffine(img_array_gs, M, (img_array_gs.shape[1], img_array_gs.shape[0]))
          img_array_shifted_ru_gs = img_to_array(shifted_lu)
          save_img(dest_dir + file_name.split(".")[0] + '_shifted_right_up_gs' + file_extension, img_array_shifted_ru_gs)
          lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_shifted_right_up_gs' + file_extension)

          # print();print(" shift right down");print()
          # cv2_imshow(img_array_shifted_ru_gs)

          # # shift the image -7 pixels to the left and 10 pixels down
          M = np.float32([[1, 0, left], [0, 1, down]])
          shifted_rd = cv2.warpAffine(img_array_gs, M, (img_array_gs.shape[1], img_array_gs.shape[0]))
          img_array_shifted_ld_gs = img_to_array(shifted_rd)
          save_img(dest_dir + file_name.split(".")[0] + '_shifted_left_down_gs' + file_extension, img_array_shifted_ld_gs)
          lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_shifted_left_down_gs' + file_extension)

          # print();print(" shift left up");print()
          # cv2_imshow(img_array_shifted_ld_gs)

      elif ind == 3:
          lst_val_0_gs.append(dest_dir + file_name.split(".")[0] + '_gs' + file_extension)
      elif ind == 4:
          lst_val_1_gs.append(dest_dir + file_name.split(".")[0] + '_gs' + file_extension)
      elif ind == 5:
          lst_test_0_gs.append(dest_dir + file_name.split(".")[0] + '_gs' + file_extension)
      elif ind == 6:
          lst_test_1_gs.append(dest_dir + file_name.split(".")[0] + '_gs' + file_extension)

# %%
# create_gs_files(train_1_images_list, tgt_train_1_image_path, 1, 0.3, 45, 7, -10, -7, 10)
# # create_gs_files(file_list, dest_dir, ind, brightness_delta=0.3, angle=90, right=7, up=-10, left=-7, down=10):
# print(len(os.listdir('/content/Dataset/Train/1')))
# print(len(os.listdir(tgt_train_1_image_path)))
# create_gs_files(train_0_images_list, tgt_train_0_image_path, 2, 0.3, 45, 7, -10, -7, 10)
# # create_gs_files(train_0_images_list, tgt_train_0_image_path, 2, 0.3, 3, 45)
# print(len(os.listdir('/content/Dataset/Train/0')))
# print(len(os.listdir(tgt_train_0_image_path)))

# %%
# # def create_gs_files(file_list, dest_dir, ind):
# def create_gs_files(file_list, dest_dir, ind, brightness_delta=0.3, contrast_factor=3, angle=90, right=7, up=-10, left=-7, down=10):
# # def create_gs_files(file_list, dest_dir, ind, brightness_delta=0.3, contrast_factor=3, angle=90):
#   # create_gs_files(train_1_images_list, tgt_train_1_image_path, 1, 0.3, 3, 45, 7, -10, -7, 10)
#   # print(file_list, dest_dir, ind)
#   lst_train_1_gs, lst_train_0_gs = [], []
#   lst_val_1_gs, lst_val_0_gs = [], []
#   lst_test_1_gs, lst_test_0_gs = [], []

#   file_extension = '.png'
#   # norm_pixel = 255.0
#   for image_file in file_list:
#       #print(image_file)
#       if image_file[0] == '.' or image_file in odd_images:                                     # if image_file = .DS_Store or an odd image then ignore
#           continue
#       img_gs = load_img(image_file, color_mode = "grayscale")                                     # convert images from colorscale to grayscale
#       # img_array_gs = img_to_array(img_gs)/255               
#       img_array_gs = img_to_array(img_gs)                     # Not normalizing the pixels
#       # norm_img_array_gs = cv2.normalize(img_array_gs, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)   # Normalizing the pixels

#       # print('==================')     
#       # print('original non-normalized')
#       # print(cv2_imshow(img_array_gs))      
#       # print('original normalized')
#       # print(cv2_imshow(img_array_gs)) 

#       file_name = image_file.split("/")[-1]                                          
#       save_img(dest_dir + file_name.split(".")[0] + '_gs' + file_extension, img_array_gs)     # CORRECT: pass 'img_array_gs' instead of 'img_array_gs'. otherwise getting an error

#       if ind == 1:
#           # insert raw training images in gray scale
#           lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_gs' + file_extension)

#           # norm_img_array_gs = cv2.normalize(img_array_gs, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
#           # img_array_normalized_gs = img_to_array(norm_img_array_gs)
#           # save_img(dest_dir + file_name.split(".")[0] + '_normalized_gs' + file_extension, img_array_normalized_gs)
#           # lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_normalized_gs' + file_extension)

#           # print();print(" Normalized 0");print()
#           # cv2_imshow(norm_img_array_gs)

#           # adjust brightness
#           bright_img_gs = tf.image.adjust_brightness(img_array_gs, delta=brightness_delta)
#           img_array_bright_gs = img_to_array(bright_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_bright_gs' + file_extension, img_array_bright_gs)
#           lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_bright_gs' + file_extension)

#           # print();print(" Brightness");print()
#           # cv2_imshow(img_array_bright_gs)
          
#           # adjust contrast
#           contrast_img_gs = tf.image.adjust_contrast(img_array_gs, contrast_factor=contrast_factor)
#           img_array_contrast_gs = img_to_array(contrast_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_contrast_gs' + file_extension, img_array_contrast_gs)
#           lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_contrast_gs' + file_extension)

#           # print();print(" contrast");print()
#           # cv2_imshow(img_array_contrast_gs)

#           # horizontal flip
#           hflip_img_gs = cv2.flip(img_array_gs, 1)
#           img_array_hflip_gs = img_to_array(hflip_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_hflip_gs' + file_extension, img_array_hflip_gs)
#           lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_hflip_gs' + file_extension)

#           # print();print(" hvip");print()
#           # cv2_imshow(img_array_hflip_gs)

#           # vertical flip
#           vflip_img_gs = cv2.flip(img_array_gs, 0)
#           img_array_vflip_gs = img_to_array(vflip_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_vflip_gs' + file_extension, img_array_vflip_gs)
#           lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_vflip_gs' + file_extension)

#           # print();print(" vvip");print()
#           # cv2_imshow(img_array_vflip_gs)

#           # random rotate 
#           rotate = int(random.uniform(-angle, angle))
#           # print('rotate ind=1', rotate)
#           h, w = img_array_gs.shape[:2]
#           M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), rotate, 1)
#           rotated_img_gs = cv2.warpAffine(img_array_gs, M, (w, h))
#           img_array_rotated_gs = img_to_array(rotated_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_' + str(rotate) + 'rotated_gs' + file_extension, img_array_rotated_gs)
#           lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_' + str(rotate) + 'rotated_gs' + file_extension)

#           # print();print(" randome rotate");print()
#           # cv2_imshow(img_array_rotated_gs)

#           # rotate 90 degrees counter clockwise (flip around x-axis)
#           img_ccw90rot_gs = cv2.transpose(img_array_gs)
#           img_ccw90rot_gs = cv2.flip(img_ccw90rot_gs, flipCode = 0)
#           rotatedccw90_img_gs = img_to_array(img_ccw90rot_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_ccw90rot_gs' + file_extension, rotatedccw90_img_gs)
#           lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_ccw90rot_gs' + file_extension)

#           # print();print(" 90ccw");print()
#           # cv2_imshow(rotatedccw90_img_gs)

#           # rotate 90 degrees clockwise(flip around y-axis)
#           img_90rot_gs = cv2.transpose(img_array_gs)
#           img_90rot_gs = cv2.flip(img_90rot_gs, flipCode = 1)
#           rotated90_img_gs = img_to_array(img_90rot_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_cw90rot_gs' + file_extension, rotated90_img_gs)
#           lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_cw90rot_gs' + file_extension)

#           # print();print(" 90cw");print()
#           # cv2_imshow(rotated90_img_gs)

#           # random zoom-in                       
#           zoomed_img_gs = zoom_in(0.6, img_array_contrast_gs)
#           img_array_zoomed_img_gs = img_to_array(zoomed_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_random_zoom_in_gs' + file_extension, img_array_zoomed_img_gs)
#           lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_random_zoom_in_gs' + file_extension)

#           # print();print(" zoom in");print()
#           # cv2_imshow(img_array_zoomed_img_gs)

#           # fill_mode = nearst
#           nearest_img_gs = fill_mode(0.8, img_array_contrast_gs)
#           img_array_nearest_img_gs = img_to_array(nearest_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_fillmode_nearest_gs' + file_extension, img_array_nearest_img_gs)
#           lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_fillmode_nearest_gs' + file_extension)

#           # print();print(" fill_mode:nearest");print()
#           # cv2_imshow(img_array_nearest_img_gs)

#           # shift the image 7 pixels to the right and -10 pixels up
#           M = np.float32([[1, 0, right], [0, 1, up]])
#           shifted_lu = cv2.warpAffine(img_array_gs, M, (img_array_gs.shape[1], img_array_gs.shape[0]))
#           img_array_shifted_ru_gs = img_to_array(shifted_lu)
#           save_img(dest_dir + file_name.split(".")[0] + '_shifted_right_up_gs' + file_extension, img_array_shifted_ru_gs)
#           lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_shifted_right_up_gs' + file_extension)

#           # print();print(" shift right down");print()
#           # cv2_imshow(img_array_shifted_ru_gs)

#           # # shift the image -7 pixels to the left and 10 pixels down
#           M = np.float32([[1, 0, left], [0, 1, down]])
#           shifted_rd = cv2.warpAffine(img_array_gs, M, (img_array_gs.shape[1], img_array_gs.shape[0]))
#           img_array_shifted_ld_gs = img_to_array(shifted_rd)
#           save_img(dest_dir + file_name.split(".")[0] + '_shifted_left_down_gs' + file_extension, img_array_shifted_ld_gs)
#           lst_train_0_gs.append(dest_dir + file_name.split(".")[0] + '_shifted_left_down_gs' + file_extension)

#           # print();print(" shift left up");print()
#           # cv2_imshow(img_array_shifted_ld_gs)

#       elif ind == 2:
#           # insert raw training images in gray scale
#           lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_gs' + file_extension)

#           # norm_img_array_gs = cv2.normalize(img_array_gs, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
#           # img_array_normalized_gs = img_to_array(norm_img_array_gs)
#           # save_img(dest_dir + file_name.split(".")[0] + '_normalized_gs' + file_extension, img_array_normalized_gs)
#           # lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_normalized_gs' + file_extension)

#           # print();print(" Normalized 1");print()
#           # cv2_imshow(norm_img_array_gs)

#            # print();print('Normalized-gray');print()
#           # cv2_imshow(lst_train_0_gs[0])

#           # adjust brightness
#           bright_img_gs = tf.image.adjust_brightness(img_array_gs, delta=brightness_delta)
#           img_array_bright_gs = img_to_array(bright_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_bright_gs' + file_extension, img_array_bright_gs)
#           lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_bright_gs' + file_extension)

#           # print();print(" Brightness");print()
#           # cv2_imshow(img_array_bright_gs)
          
#           # adjust contrast
#           contrast_img_gs = tf.image.adjust_contrast(img_array_gs, contrast_factor=contrast_factor)
#           img_array_contrast_gs = img_to_array(contrast_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_contrast_gs' + file_extension, img_array_contrast_gs)
#           lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_contrast_gs' + file_extension)

#           # print();print(" contrast");print()
#           # cv2_imshow(img_array_contrast_gs)

#           # horizontal flip
#           hflip_img_gs = cv2.flip(img_array_gs, 1)
#           img_array_hflip_gs = img_to_array(hflip_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_hflip_gs' + file_extension, img_array_hflip_gs)
#           lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_hflip_gs' + file_extension)

#           # print();print(" hvip");print()
#           # cv2_imshow(img_array_hflip_gs)

#           # vertical flip
#           vflip_img_gs = cv2.flip(img_array_gs, 0)
#           img_array_vflip_gs = img_to_array(vflip_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_vflip_gs' + file_extension, img_array_vflip_gs)
#           lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_vflip_gs' + file_extension)

#           # print();print(" vvip");print()
#           # cv2_imshow(img_array_vflip_gs)

#           # random rotate 
#           rotate = int(random.uniform(-angle, angle))
#           # print('rotate ind=1', rotate)
#           h, w = img_array_gs.shape[:2]
#           M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), rotate, 1)
#           rotated_img_gs = cv2.warpAffine(img_array_gs, M, (w, h))
#           img_array_rotated_gs = img_to_array(rotated_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_' + str(rotate) + 'rotated_gs' + file_extension, img_array_rotated_gs)
#           lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_' + str(rotate) + 'rotated_gs' + file_extension)

#           # print();print(" randome rotate");print()
#           # cv2_imshow(img_array_rotated_gs)

#           # rotate 90 degrees counter clockwise (flip around x-axis)
#           img_ccw90rot_gs = cv2.transpose(img_array_gs)
#           img_ccw90rot_gs = cv2.flip(img_ccw90rot_gs, flipCode = 0)
#           rotatedccw90_img_gs = img_to_array(img_ccw90rot_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_ccw90rot_gs' + file_extension, rotatedccw90_img_gs)
#           lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_ccw90rot_gs' + file_extension)

#           # print();print(" 90ccw");print()
#           # cv2_imshow(rotatedccw90_img_gs)

#           # rotate 90 degrees clockwise(flip around y-axis)
#           img_90rot_gs = cv2.transpose(img_array_gs)
#           img_90rot_gs = cv2.flip(img_90rot_gs, flipCode = 1)
#           rotated90_img_gs = img_to_array(img_90rot_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_cw90rot_gs' + file_extension, rotated90_img_gs)
#           lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_cw90rot_gs' + file_extension)

#           # print();print(" 90cw");print()
#           # cv2_imshow(rotated90_img_gs)

#           # random zoom-in                       
#           zoomed_img_gs = zoom_in(0.6, img_array_contrast_gs)
#           img_array_zoomed_img_gs = img_to_array(zoomed_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_random_zoom_in_gs' + file_extension, img_array_zoomed_img_gs)
#           lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_random_zoom_in_gs' + file_extension)

#           # print();print(" zoom in");print()
#           # cv2_imshow(img_array_zoomed_img_gs)

#           # fill_mode = nearst
#           nearest_img_gs = fill_mode(0.8, img_array_contrast_gs)
#           img_array_nearest_img_gs = img_to_array(nearest_img_gs)
#           save_img(dest_dir + file_name.split(".")[0] + '_fillmode_nearest_gs' + file_extension, img_array_nearest_img_gs)
#           lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_fillmode_nearest_gs' + file_extension)

#           # print();print(" fill_mode:nearest");print()
#           # cv2_imshow(img_array_nearest_img_gs)

#           # shift the image 7 pixels to the right and -10 pixels up
#           M = np.float32([[1, 0, right], [0, 1, up]])
#           shifted_lu = cv2.warpAffine(img_array_gs, M, (img_array_gs.shape[1], img_array_gs.shape[0]))
#           img_array_shifted_ru_gs = img_to_array(shifted_lu)
#           save_img(dest_dir + file_name.split(".")[0] + '_shifted_right_up_gs' + file_extension, img_array_shifted_ru_gs)
#           lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_shifted_right_up_gs' + file_extension)

#           # print();print(" shift right down");print()
#           # cv2_imshow(img_array_shifted_ru_gs)

#           # # shift the image -7 pixels to the left and 10 pixels down
#           M = np.float32([[1, 0, left], [0, 1, down]])
#           shifted_rd = cv2.warpAffine(img_array_gs, M, (img_array_gs.shape[1], img_array_gs.shape[0]))
#           img_array_shifted_ld_gs = img_to_array(shifted_rd)
#           save_img(dest_dir + file_name.split(".")[0] + '_shifted_left_down_gs' + file_extension, img_array_shifted_ld_gs)
#           lst_train_1_gs.append(dest_dir + file_name.split(".")[0] + '_shifted_left_down_gs' + file_extension)

#           # print();print(" shift left up");print()
#           # cv2_imshow(img_array_shifted_ld_gs)

#       elif ind == 3:
#           lst_val_0_gs.append(dest_dir + file_name.split(".")[0] + '_gs' + file_extension)
#       elif ind == 4:
#           lst_val_1_gs.append(dest_dir + file_name.split(".")[0] + '_gs' + file_extension)
#       elif ind == 5:
#           lst_test_0_gs.append(dest_dir + file_name.split(".")[0] + '_gs' + file_extension)
#       elif ind == 6:
#           lst_test_1_gs.append(dest_dir + file_name.split(".")[0] + '_gs' + file_extension)

# %%
# create_gs_files(train_1_images_list, tgt_train_1_image_path, 1, 0.3, 45, 7, -10, -7, 10)
# print(len(os.listdir('/content/Dataset/Train/1')))
# print(len(os.listdir(tgt_train_1_image_path)))
# create_gs_files(train_0_images_list, tgt_train_0_image_path, 2, 0.3, 3, 45, 7, -10, -7, 10)
# # create_gs_files(train_0_images_list, tgt_train_0_image_path, 2, 0.3, 3, 45)
# print(len(os.listdir('/content/Dataset/Train/0')))
# print(len(os.listdir(tgt_train_0_image_path)))

# %%
# file1 = '/content/processed_images/train/1/9023_idx5_x1351_y1751_class1_gs.png'
# # /content/Dataset/Train/0/16551_idx5_x1751_y801_class0.png 
# # print(path + '10269_idx5_x1351_y801_class1_gs.png' )
# file2 = '/content/processed_images/train/1/9175_idx5_x1801_y201_class1_gs.png'
# file3 = '/content/processed_images/train/1/9255_idx5_x2901_y901_class1_gs.png'

# org_img = load_img(file1)
# org_img_arry = img_to_array(org_img)
# print("  Original:50x50(RGB)");print()
# cv2_imshow(org_img_arry)

# org_img = load_img(file2)
# org_img_arry = img_to_array(org_img)
# print("  Original:50x50(RGB)");print()
# cv2_imshow(org_img_arry)

# org_img = load_img(file3)
# org_img_arry = img_to_array(org_img)
# print("  Original:50x50(RGB)");print()
# cv2_imshow(org_img_arry)

# %%
# len(os.listdir('/content/Dataset/Validate/0'))

# %% [markdown]
# # Store Processed Images to New Directory
# - Convert color to gray scale
# - Append augmented images

# %%
print(train_1_images_list[0])
print(train_0_images_list[0])
# Out:
# /content/Dataset/Train/1/10269_idx5_x1351_y801_class1.png
# /content/Dataset/Train/0/9256_idx5_x1901_y51_class0.png

# %%
print(tgt_train_1_image_path)
print(tgt_train_0_image_path)
# Out:
# /content/processed_images/train/1/
# /content/processed_images/train/0/

# %%
create_gs_files(train_1_images_list, tgt_train_1_image_path, 1, 0.3, 3, 45, 7, -10, -7, 10)
print(len(os.listdir('/content/Dataset/Train/1')))
print(len(os.listdir(tgt_train_1_image_path)))
create_gs_files(train_0_images_list, tgt_train_0_image_path, 2, 0.3, 3, 45, 7, -10, -7, 10)
print(len(os.listdir('/content/Dataset/Train/0')))
print(len(os.listdir(tgt_train_0_image_path)))

create_gs_files(val_0_images_list, tgt_val_0_image_path, 3, 0.3, 3, 45, 7, -10, -7, 10)
print(len(os.listdir('/content/Dataset/Validate/1')))
print(len(os.listdir(tgt_val_1_image_path)))
create_gs_files(val_1_images_list, tgt_val_1_image_path, 4, 0.3, 3, 45, 7, -10, -7, 10)
print(len(os.listdir('/content/Dataset/Validate/0')))
print(len(os.listdir(tgt_val_0_image_path)))

create_gs_files(test_0_images_list, tgt_test_0_image_path, 5, 0.3, 3, 45, 7, -10, -7, 10)
print(len(os.listdir('/content/Dataset/Test/1')))
print(len(os.listdir(tgt_test_1_image_path)))
create_gs_files(test_1_images_list, tgt_test_1_image_path, 6, 0.3, 3, 45, 7, -10, -7, 10)
print(len(os.listdir('/content/Dataset/Test/0')))
print(len(os.listdir(tgt_test_0_image_path)))
# Out:
# 401
# 4800
# 401
# 4764
# 101
# 0
# 101
# 97
# 101
# 0
# 101
# 99

# %%
# !ls -ltr /content/Dataset/Train/1/*.png|wc -l
# !ls -ltr /content/Dataset/Train/0/*.png|wc -l
# Out:
# 400
# 400

# %% [markdown]
# # Check the Number of Processed Images in Each Class of Training Dataset

# %%
# !ls -ltra /content/processed_images/train/1/*.png|wc -l
# !ls -ltra /content/processed_images/train/0/*.png|wc -l
# !ls -ltra /content/processed_images/test/1/*.png|wc -l
# !ls -ltra /content/processed_images/test/0/*.png|wc -l
# !ls -ltra /content/processed_images/val/1/*.png|wc -l
# !ls -ltra /content/processed_images/val/0/*.png|wc -l
# Out:
# 4800
# 4764
# 100
# 99
# 100
# 97

# %%
# !zip -r /content/processed_images_updated.zip /content/processed_images
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/processed_images/train/0/9225_idx5_x851_y801_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9320_idx5_x2201_y1601_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12826_idx5_x501_y1501_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10272_idx5_x3351_y2001_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14192_idx5_x1751_y101_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10299_idx5_x451_y651_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9265_idx5_x2351_y1201_class0_-7rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9256_idx5_x1901_y51_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12820_idx5_x1801_y1451_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10291_idx5_x3251_y401_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13462_idx5_x2751_y851_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10259_idx5_x1201_y1951_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12911_idx5_x2301_y251_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12911_idx5_x1851_y601_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8918_idx5_x551_y1001_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13022_idx5_x2551_y251_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12910_idx5_x401_y251_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12826_idx5_x501_y1501_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13021_idx5_x1501_y551_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12810_idx5_x2451_y2301_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12821_idx5_x901_y451_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13021_idx5_x2351_y1001_class0_-6rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10268_idx5_x1351_y51_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8956_idx5_x2551_y1901_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16550_idx5_x851_y1551_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12910_idx5_x2201_y801_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14210_idx5_x1101_y1801_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12931_idx5_x901_y1751_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12821_idx5_x501_y451_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10274_idx5_x1151_y1851_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12823_idx5_x3551_y1651_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14155_idx5_x3501_y2051_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15472_idx5_x3051_y2201_class0_-2rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8974_idx5_x251_y1151_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15472_idx5_x3051_y2201_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10295_idx5_x1251_y751_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10288_idx5_x2101_y2101_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12905_idx5_x1851_y2301_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9043_idx5_x1651_y601_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9266_idx5_x3201_y751_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10262_idx5_x501_y1001_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12954_idx5_x1251_y801_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9322_idx5_x501_y1151_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16555_idx5_x351_y301_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13401_idx5_x1351_y1351_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15902_idx5_x301_y751_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12933_idx5_x1051_y551_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9265_idx5_x1901_y1901_class0_-4rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8975_idx5_x3551_y1701_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9176_idx5_x701_y2101_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10290_idx5_x3101_y1101_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12930_idx5_x451_y851_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13462_idx5_x2751_y851_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15473_idx5_x1151_y351_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12905_idx5_x1851_y2301_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12896_idx5_x751_y1601_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8951_idx5_x2151_y951_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9126_idx5_x1651_y601_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8867_idx5_x2201_y1201_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16552_idx5_x701_y851_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9135_idx5_x1001_y651_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12870_idx5_x2551_y201_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12810_idx5_x3201_y501_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12934_idx5_x1601_y2551_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14189_idx5_x3001_y1551_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12934_idx5_x451_y1601_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16550_idx5_x601_y2401_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13460_idx5_x1401_y1101_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12819_idx5_x2601_y651_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12878_idx5_x601_y2651_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10264_idx5_x2451_y1201_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13460_idx5_x301_y1201_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8867_idx5_x2801_y1401_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15513_idx5_x651_y801_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12911_idx5_x2301_y251_class0_-31rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10301_idx5_x2201_y1201_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8918_idx5_x301_y151_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12911_idx5_x2351_y651_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10302_idx5_x1351_y301_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9265_idx5_x1901_y1901_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14079_idx5_x2301_y1201_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12934_idx5_x1101_y1401_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12824_idx5_x1901_y951_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10259_idx5_x1551_y1101_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9181_idx5_x401_y1051_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12910_idx5_x2201_y801_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14305_idx5_x2201_y551_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9324_idx5_x851_y1501_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12823_idx5_x1751_y1951_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12934_idx5_x2901_y2551_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16014_idx5_x1751_y1151_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9259_idx5_x1601_y951_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10272_idx5_x1851_y1301_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10300_idx5_x3201_y651_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13460_idx5_x1751_y901_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15516_idx5_x2901_y1951_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13460_idx5_x1751_y901_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12880_idx5_x451_y701_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9256_idx5_x1901_y51_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16555_idx5_x351_y301_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9383_idx5_x1801_y1101_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10274_idx5_x1151_y1851_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8864_idx5_x3051_y1651_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9177_idx5_x1151_y151_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9382_idx5_x201_y1451_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12934_idx5_x1601_y2551_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10254_idx5_x651_y1451_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12869_idx5_x651_y1751_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9075_idx5_x2201_y651_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9250_idx5_x1801_y1501_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8975_idx5_x1301_y2551_class0_-35rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10268_idx5_x1351_y51_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9126_idx5_x2751_y1151_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10290_idx5_x3101_y1101_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14189_idx5_x3001_y1551_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8956_idx5_x2551_y1901_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10278_idx5_x901_y1501_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10262_idx5_x301_y1151_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9176_idx5_x701_y2101_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9322_idx5_x1651_y301_class0_39rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9126_idx5_x1651_y1701_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12749_idx5_x3301_y401_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9261_idx5_x1151_y1051_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12905_idx5_x2251_y1351_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9250_idx5_x2201_y451_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15513_idx5_x1351_y851_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8867_idx5_x2551_y1901_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10282_idx5_x1351_y2501_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16550_idx5_x851_y1551_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8918_idx5_x1101_y751_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10292_idx5_x3451_y1151_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10301_idx5_x1851_y601_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15513_idx5_x1201_y1501_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8975_idx5_x1401_y2501_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9123_idx5_x1051_y1801_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9255_idx5_x1901_y801_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8956_idx5_x2601_y1251_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13459_idx5_x1301_y751_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9256_idx5_x1901_y51_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9265_idx5_x151_y851_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9225_idx5_x851_y801_class0_15rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8951_idx5_x2151_y951_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16550_idx5_x1601_y701_class0_4rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12930_idx5_x2601_y1651_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10259_idx5_x1851_y551_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10264_idx5_x2451_y1201_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10254_idx5_x1051_y1651_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10272_idx5_x1851_y1301_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8867_idx5_x2251_y901_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12932_idx5_x1151_y51_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12819_idx5_x3051_y2401_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9322_idx5_x1301_y1451_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13460_idx5_x351_y1651_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8918_idx5_x1101_y751_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14156_idx5_x2001_y401_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10268_idx5_x2401_y1651_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12870_idx5_x2551_y201_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9265_idx5_x3101_y1951_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9023_idx5_x651_y1551_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10274_idx5_x1051_y851_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16085_idx5_x2801_y1501_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10282_idx5_x1151_y2251_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8980_idx5_x601_y601_class0_11rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9319_idx5_x1601_y501_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14155_idx5_x2401_y2051_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9078_idx5_x2201_y2001_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16570_idx5_x2801_y1151_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9261_idx5_x1151_y1051_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8975_idx5_x1401_y2501_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12750_idx5_x351_y1401_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15473_idx5_x1401_y251_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10302_idx5_x2801_y551_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9255_idx5_x1901_y801_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9265_idx5_x1301_y301_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9036_idx5_x1851_y351_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9250_idx5_x1451_y401_class0_-4rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10276_idx5_x951_y351_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15513_idx5_x1201_y1501_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12932_idx5_x1651_y201_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10302_idx5_x1351_y301_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12910_idx5_x3351_y1101_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12817_idx5_x2401_y201_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15513_idx5_x651_y801_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12750_idx5_x351_y1401_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14157_idx5_x2551_y1201_class0_3rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12935_idx5_x701_y801_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13693_idx5_x2151_y751_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13460_idx5_x351_y1651_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8959_idx5_x501_y1201_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12878_idx5_x601_y2651_class0_0rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12886_idx5_x751_y1001_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12749_idx5_x3301_y401_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13693_idx5_x2601_y2101_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16550_idx5_x2101_y501_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10282_idx5_x1151_y2251_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8975_idx5_x3551_y1701_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10259_idx5_x2451_y1451_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16550_idx5_x1601_y701_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10292_idx5_x3451_y1151_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10308_idx5_x3101_y1651_class0_30rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9075_idx5_x2601_y2351_class0_-21rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9076_idx5_x2451_y2301_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10282_idx5_x1151_y2251_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10308_idx5_x751_y1951_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12935_idx5_x701_y801_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14156_idx5_x2501_y2151_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13462_idx5_x2751_y851_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10272_idx5_x3351_y2001_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12910_idx5_x401_y251_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10276_idx5_x251_y501_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15473_idx5_x1401_y251_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8867_idx5_x2201_y1201_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12947_idx5_x2801_y651_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9323_idx5_x1501_y1851_class0_-5rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13693_idx5_x1401_y1701_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10292_idx5_x3351_y951_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14191_idx5_x3251_y2501_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12930_idx5_x501_y1451_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9126_idx5_x1651_y601_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10272_idx5_x101_y801_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10262_idx5_x301_y1151_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9345_idx5_x2001_y2001_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9265_idx5_x151_y851_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8974_idx5_x1251_y951_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12820_idx5_x1801_y1451_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12954_idx5_x2301_y351_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9076_idx5_x2601_y2051_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9383_idx5_x1801_y1101_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12821_idx5_x2301_y201_class0_-26rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13916_idx5_x2351_y951_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10276_idx5_x251_y501_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12895_idx5_x3401_y501_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10285_idx5_x851_y1201_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14079_idx5_x2701_y1151_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14305_idx5_x2201_y551_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12933_idx5_x1051_y551_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13024_idx5_x2201_y1401_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16550_idx5_x601_y2401_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12930_idx5_x1901_y1301_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15473_idx5_x1151_y351_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15516_idx5_x2901_y1951_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12910_idx5_x2951_y1151_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12932_idx5_x1151_y51_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9322_idx5_x501_y1151_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12910_idx5_x401_y251_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8956_idx5_x2551_y1901_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9022_idx5_x201_y651_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13687_idx5_x2551_y801_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10254_idx5_x2151_y451_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9265_idx5_x151_y851_class0_-24rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10272_idx5_x1601_y851_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8867_idx5_x1401_y1801_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12930_idx5_x501_y1451_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16550_idx5_x1351_y2001_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13459_idx5_x1651_y951_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12750_idx5_x351_y1401_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9322_idx5_x2351_y1151_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10274_idx5_x1051_y851_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12870_idx5_x2551_y201_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12911_idx5_x2351_y651_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12819_idx5_x1151_y451_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12895_idx5_x3401_y501_class0_-22rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14191_idx5_x3251_y2501_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10295_idx5_x901_y1451_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14156_idx5_x2501_y2151_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12908_idx5_x1651_y1701_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12931_idx5_x901_y1751_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9250_idx5_x1451_y401_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15632_idx5_x3101_y2551_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12826_idx5_x501_y1501_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9043_idx5_x1651_y601_class0_11rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15902_idx5_x2951_y2501_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12877_idx5_x301_y1351_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10261_idx5_x2351_y551_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12749_idx5_x2201_y1401_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16550_idx5_x851_y1551_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9323_idx5_x1501_y1851_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13591_idx5_x2401_y2301_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9345_idx5_x1951_y2651_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12822_idx5_x1951_y1151_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8867_idx5_x2201_y1201_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13021_idx5_x2201_y351_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10275_idx5_x651_y651_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10268_idx5_x2451_y1551_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8956_idx5_x2901_y651_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12896_idx5_x751_y1601_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12897_idx5_x2251_y2101_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13459_idx5_x401_y851_class0_-30rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10279_idx5_x2451_y301_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13020_idx5_x2051_y1251_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10259_idx5_x1851_y551_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9324_idx5_x851_y1501_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13401_idx5_x1351_y1351_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10282_idx5_x1151_y2251_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12911_idx5_x2351_y651_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12878_idx5_x601_y2651_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10282_idx5_x2351_y2001_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9250_idx5_x2201_y451_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13020_idx5_x2051_y1251_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12929_idx5_x1101_y1_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8956_idx5_x2551_y1901_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8951_idx5_x2151_y951_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9324_idx5_x851_y1501_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10273_idx5_x1651_y251_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10282_idx5_x1151_y2251_class0_35rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16570_idx5_x601_y1201_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12905_idx5_x2251_y1351_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9176_idx5_x701_y2101_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12933_idx5_x1051_y551_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9324_idx5_x801_y1651_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12892_idx5_x1001_y1051_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10259_idx5_x2351_y251_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9043_idx5_x1651_y601_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10300_idx5_x3201_y651_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15513_idx5_x1001_y1251_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9266_idx5_x3201_y751_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9265_idx5_x2351_y1201_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14156_idx5_x601_y1501_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9261_idx5_x1151_y1051_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16568_idx5_x2851_y351_class0_-5rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16550_idx5_x2101_y501_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14190_idx5_x2401_y501_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12749_idx5_x2201_y551_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9322_idx5_x1301_y1451_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9322_idx5_x201_y1251_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8956_idx5_x2601_y1251_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10288_idx5_x2101_y2101_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8975_idx5_x1301_y2551_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16555_idx5_x451_y301_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14079_idx5_x2301_y1201_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12908_idx5_x1451_y801_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12905_idx5_x2151_y2151_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9123_idx5_x2051_y1401_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12869_idx5_x651_y1751_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8974_idx5_x251_y1151_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13021_idx5_x2201_y351_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8956_idx5_x2751_y501_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9075_idx5_x1951_y1051_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12817_idx5_x2401_y201_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10262_idx5_x301_y1151_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9022_idx5_x201_y651_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10285_idx5_x1701_y551_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12954_idx5_x2301_y351_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14211_idx5_x1801_y1701_class0_-6rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13591_idx5_x3101_y1551_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13460_idx5_x351_y1651_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10300_idx5_x2951_y1351_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8865_idx5_x2101_y1051_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13024_idx5_x1051_y1301_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9346_idx5_x951_y1151_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12929_idx5_x1101_y1_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8975_idx5_x3551_y1701_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10273_idx5_x1651_y251_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9029_idx5_x701_y201_class0_-19rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9257_idx5_x301_y1851_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13400_idx5_x2001_y2251_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8959_idx5_x1751_y2201_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9075_idx5_x2601_y2351_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10307_idx5_x2101_y751_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9076_idx5_x2451_y2301_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13591_idx5_x3101_y1551_class0_-34rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14155_idx5_x2401_y2051_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12879_idx5_x201_y301_class0_20rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12905_idx5_x2251_y1351_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10260_idx5_x2401_y601_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10300_idx5_x3201_y651_class0_-19rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12910_idx5_x2951_y1151_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12749_idx5_x2201_y1401_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9173_idx5_x1151_y351_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9125_idx5_x1551_y1301_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12751_idx5_x801_y1601_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9265_idx5_x151_y851_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13460_idx5_x1351_y851_class0_40rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9265_idx5_x1301_y301_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13024_idx5_x2201_y1401_class0_-4rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12810_idx5_x3201_y501_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16085_idx5_x901_y1451_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9319_idx5_x1601_y501_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12905_idx5_x1851_y2301_class0_18rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8867_idx5_x2801_y1401_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10308_idx5_x751_y1951_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12826_idx5_x501_y1501_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12870_idx5_x901_y1351_class0_-41rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10275_idx5_x651_y651_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8975_idx5_x1401_y2501_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16570_idx5_x601_y1201_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10301_idx5_x651_y1351_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10282_idx5_x1351_y2501_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12826_idx5_x501_y1501_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9382_idx5_x201_y1451_class0_11rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10260_idx5_x2401_y601_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14079_idx5_x2701_y1151_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12886_idx5_x751_y1001_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9250_idx5_x1801_y1501_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9123_idx5_x2051_y1401_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12930_idx5_x451_y851_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9023_idx5_x651_y1551_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12929_idx5_x1101_y1_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13459_idx5_x401_y851_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10255_idx5_x1301_y351_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13916_idx5_x2351_y951_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12910_idx5_x401_y251_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12826_idx5_x501_y1501_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12954_idx5_x2301_y351_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9320_idx5_x3301_y1851_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13400_idx5_x1301_y2051_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10259_idx5_x2101_y51_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12935_idx5_x1301_y701_class0_-17rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12819_idx5_x1151_y451_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9181_idx5_x551_y751_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10301_idx5_x1501_y1551_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9346_idx5_x951_y1151_class0_22rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10255_idx5_x1301_y351_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12626_idx5_x1551_y1001_class0_-36rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8956_idx5_x2901_y651_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10259_idx5_x1201_y1951_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9073_idx5_x1851_y51_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12896_idx5_x1551_y1051_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9125_idx5_x1551_y1301_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8867_idx5_x1401_y1801_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13024_idx5_x2201_y1401_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14155_idx5_x2851_y2201_class0_8rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12821_idx5_x501_y451_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12905_idx5_x2251_y1351_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9176_idx5_x1951_y1251_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10286_idx5_x1051_y901_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10268_idx5_x1351_y51_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16568_idx5_x2851_y351_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14079_idx5_x2301_y1201_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10272_idx5_x3051_y2051_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/14156_idx5_x2001_y401_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15513_idx5_x1201_y1501_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12869_idx5_x651_y1751_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8959_idx5_x1751_y2201_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12826_idx5_x3501_y1201_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12626_idx5_x1551_y1001_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8864_idx5_x1901_y951_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9029_idx5_x2801_y451_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10282_idx5_x801_y2151_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10292_idx5_x3451_y1151_class0_-19rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9225_idx5_x851_y801_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12626_idx5_x1551_y1001_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12877_idx5_x301_y1351_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10282_idx5_x1151_y2251_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12749_idx5_x1101_y2001_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10261_idx5_x2351_y551_class0_22rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12891_idx5_x2801_y1451_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12929_idx5_x1101_y1_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9322_idx5_x501_y1151_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9290_idx5_x2501_y951_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10300_idx5_x2201_y1751_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9036_idx5_x1851_y351_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12826_idx5_x3501_y1201_class0_40rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16014_idx5_x1401_y251_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9320_idx5_x3301_y1851_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12932_idx5_x1151_y51_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13460_idx5_x2001_y651_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10307_idx5_x2151_y401_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10272_idx5_x901_y1401_class0_fillmode_nearest_gs.png (stored 0%)
#   adding: content/processed_images/train/0/16570_idx5_x601_y1201_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10272_idx5_x101_y801_class0_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9043_idx5_x1651_y601_class0_hflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12910_idx5_x401_y251_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9250_idx5_x1801_y1501_class0_ccw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10274_idx5_x851_y651_class0_random_zoom_in_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10259_idx5_x2351_y251_class0_bright_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10274_idx5_x1151_y1851_class0_43rotated_gs.png (stored 0%)
#   adding: content/processed_images/train/0/15510_idx5_x1201_y1951_class0_shifted_right_up_gs.png (stored 0%)
#   adding: content/processed_images/train/0/13021_idx5_x2201_y351_class0_cw90rot_gs.png (stored 0%)
#   adding: content/processed_images/train/0/10282_idx5_x1351_y2501_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12819_idx5_x1151_y451_class0_contrast_gs.png (stored 0%)
#   adding: content/processed_images/train/0/9346_idx5_x951_y1151_class0_vflip_gs.png (stored 0%)
#   adding: content/processed_images/train/0/8956_idx5_x2601_y1251_class0_shifted_left_down_gs.png (stored 0%)
#   adding: content/processed_images/train/0/12930_idx5_x1901_y1301_class0_fillmode_nearest_gs.png (stored 0%)
# ...
#   adding: content/processed_images/test/1/12897_idx5_x2051_y401_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9023_idx5_x2101_y1751_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9041_idx5_x2001_y2001_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/14155_idx5_x3101_y651_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10302_idx5_x701_y1351_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12930_idx5_x2151_y2151_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10275_idx5_x1201_y1001_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/13694_idx5_x1651_y1801_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12821_idx5_x1751_y1451_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9077_idx5_x801_y1801_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/16896_idx5_x801_y1501_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9176_idx5_x1851_y2051_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/14191_idx5_x2001_y2401_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12890_idx5_x901_y1201_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12752_idx5_x1801_y601_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9023_idx5_x2051_y1951_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/15902_idx5_x2101_y1051_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12883_idx5_x901_y351_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10273_idx5_x2351_y1501_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9041_idx5_x2451_y1051_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10299_idx5_x351_y1651_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12867_idx5_x1251_y1151_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/14304_idx5_x1651_y701_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10273_idx5_x1851_y701_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10308_idx5_x1001_y1951_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12818_idx5_x2651_y1401_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12826_idx5_x2901_y651_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/15472_idx5_x1501_y1351_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/15902_idx5_x3001_y901_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12933_idx5_x1051_y801_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10308_idx5_x2101_y751_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12947_idx5_x1751_y1951_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/15903_idx5_x1251_y701_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10286_idx5_x1301_y701_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/13404_idx5_x2501_y1651_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10275_idx5_x2201_y1201_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12751_idx5_x751_y2401_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/15840_idx5_x951_y1301_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9267_idx5_x1951_y1101_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10260_idx5_x1101_y451_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9262_idx5_x301_y1051_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10308_idx5_x1001_y1201_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/14155_idx5_x1851_y1451_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10278_idx5_x1051_y1201_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9077_idx5_x851_y1101_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12881_idx5_x551_y1251_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/16165_idx5_x2151_y1101_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9124_idx5_x1001_y1001_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/14211_idx5_x1451_y1251_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/14156_idx5_x2551_y1501_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/14081_idx5_x2601_y151_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/15473_idx5_x2351_y1151_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12870_idx5_x401_y2501_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10258_idx5_x1001_y1051_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12929_idx5_x1151_y701_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/13613_idx5_x2651_y1351_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12882_idx5_x1301_y401_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/16568_idx5_x2051_y901_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12884_idx5_x1351_y601_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/15471_idx5_x1851_y901_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9345_idx5_x2801_y201_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12891_idx5_x1601_y1501_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/14082_idx5_x1551_y1701_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/13021_idx5_x1701_y501_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/8980_idx5_x1101_y1351_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12818_idx5_x3051_y1601_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10292_idx5_x1651_y1901_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/15516_idx5_x1651_y1901_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/15510_idx5_x2601_y1401_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12242_idx5_x2001_y1151_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/13616_idx5_x1851_y951_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/10273_idx5_x2001_y1901_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9346_idx5_x1951_y2401_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9081_idx5_x2851_y1101_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/12949_idx5_x1851_y701_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/13021_idx5_x1951_y701_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/1/9176_idx5_x2201_y1751_class1_gs.png (stored 0%)
#   adding: content/processed_images/test/0/ (stored 0%)
#   adding: content/processed_images/test/0/9023_idx5_x151_y1001_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9382_idx5_x601_y1151_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/8975_idx5_x251_y851_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10290_idx5_x1701_y1501_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/8984_idx5_x1451_y1651_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9083_idx5_x401_y301_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9259_idx5_x1551_y2351_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13019_idx5_x2801_y1401_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/14154_idx5_x801_y351_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/16551_idx5_x1751_y2301_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12870_idx5_x2951_y2601_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9266_idx5_x1201_y801_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9290_idx5_x301_y1401_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12884_idx5_x1801_y1301_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9078_idx5_x2651_y1601_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9041_idx5_x1801_y1901_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12954_idx5_x2301_y1351_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/8975_idx5_x2151_y2401_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13402_idx5_x2851_y1901_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13400_idx5_x1301_y2701_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9266_idx5_x3101_y1101_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10305_idx5_x1501_y1101_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9036_idx5_x3401_y951_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10290_idx5_x1201_y251_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/14210_idx5_x1901_y1801_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10258_idx5_x601_y751_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9075_idx5_x251_y1251_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/14155_idx5_x2301_y2101_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13458_idx5_x151_y1001_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/8913_idx5_x2001_y901_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/8864_idx5_x3151_y1101_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9323_idx5_x851_y2301_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12909_idx5_x1751_y901_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9381_idx5_x2451_y2151_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10259_idx5_x51_y951_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10260_idx5_x2551_y751_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13459_idx5_x101_y1001_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/8951_idx5_x1451_y1601_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13404_idx5_x1501_y2101_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/15516_idx5_x1651_y1301_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13693_idx5_x451_y1851_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9382_idx5_x2251_y1751_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13916_idx5_x751_y601_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9323_idx5_x1951_y1651_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9135_idx5_x501_y151_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12826_idx5_x601_y1401_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/15902_idx5_x251_y1301_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12751_idx5_x1451_y601_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9029_idx5_x51_y801_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/8956_idx5_x301_y501_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/8956_idx5_x451_y401_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13693_idx5_x3201_y1901_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12818_idx5_x1001_y1751_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10302_idx5_x2701_y401_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9081_idx5_x2051_y651_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9259_idx5_x2351_y1501_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10307_idx5_x951_y1251_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12821_idx5_x2401_y501_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10264_idx5_x2251_y551_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13400_idx5_x2301_y501_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10259_idx5_x2501_y651_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13400_idx5_x2451_y2351_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13459_idx5_x2501_y851_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12821_idx5_x1151_y101_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12906_idx5_x501_y751_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/8975_idx5_x1451_y2501_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10288_idx5_x751_y651_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13400_idx5_x3351_y1151_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13022_idx5_x1751_y1101_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9036_idx5_x3051_y751_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9254_idx5_x3351_y1051_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/14321_idx5_x1051_y801_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/14210_idx5_x1001_y1901_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10259_idx5_x1851_y1151_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13401_idx5_x1001_y1301_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10293_idx5_x1101_y1151_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12878_idx5_x2101_y2001_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10260_idx5_x501_y801_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12892_idx5_x601_y1051_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9266_idx5_x1601_y51_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/14154_idx5_x1201_y301_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12880_idx5_x2251_y801_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10305_idx5_x2201_y1301_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10300_idx5_x2051_y801_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9123_idx5_x651_y1801_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12908_idx5_x1351_y1501_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12949_idx5_x1851_y1651_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/15632_idx5_x2001_y1501_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10305_idx5_x751_y1951_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12954_idx5_x1851_y2701_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12898_idx5_x1701_y251_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12900_idx5_x2701_y1401_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/15516_idx5_x1051_y851_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/13591_idx5_x2951_y701_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10291_idx5_x2901_y701_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/9322_idx5_x1201_y1001_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/8914_idx5_x151_y1201_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/10293_idx5_x1751_y1651_class0_gs.png (stored 0%)
#   adding: content/processed_images/test/0/12897_idx5_x2601_y1601_class0_gs.png (stored 0%)

# %% [markdown]
# # Define Image Data Generator
# : 1200 given raw images + augmented images

# %%
batch_size = 64
random_state = 1234
image_size = 50

def data_generator(image_size): 
  processed_images_train_path = '/content/processed_images/train'           # contains augmented images with original images (4782 = IDC(1): 2400 + IDC(1): 2382)
  processed_images_validation_path = '/content/processed_images/val'
  processed_images_test_path = '/content/processed_images/test'

  # train_datagen = ImageDataGenerator(rescale = 1./255,
  #                                  horizontal_flip = True,
  #                                  vertical_flip = True,
  #                                  rotation_range = 180,
  #                                  zoom_range = 0.4, 
  #                                  width_shift_range = 0.3,
  #                                  height_shift_range = 0.3,
  #                                  shear_range = 0.3
  #                                  #,preprocessing_function = custom_augmentation 
  #                                 )

  # # Validation data generator
  # val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
  #     rescale = 1.0/255
  #     )

  # # Test data generator
  # test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
  #     rescale = 1.0/255
  #     )


  datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1.0/255)          # Normalize image pixels to the range of [0,1]

  train_data_generator = datagen.flow_from_directory(processed_images_train_path,
                                                                      target_size = (image_size, image_size),
                                                                      class_mode = 'categorical',
                                                                      batch_size = batch_size,
                                                                      color_mode = 'rgb',
                                                                      shuffle = True,
                                                                      seed = random_state
                                                                      )
  val_data_generator = datagen.flow_from_directory(processed_images_validation_path,
                                                                  target_size = (image_size, image_size),
                                                                  class_mode = 'categorical',
                                                                  batch_size = batch_size,
                                                                  color_mode = 'rgb',
                                                                  shuffle = True,
                                                                  seed = random_state
                                                                  )
  test_data_generator = datagen.flow_from_directory(processed_images_test_path,
                                                                    target_size = (image_size, image_size),
                                                                    batch_size = batch_size,
                                                                    class_mode = 'categorical',
                                                                    color_mode = 'rgb',
                                                                    shuffle = False,
                                                                    seed = random_state
                                                                    )
  return train_data_generator, val_data_generator, test_data_generator

# train_data_generator, val_data_generator, test_data_generator = data_generator(image_size)
